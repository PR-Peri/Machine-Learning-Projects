# %%
### Imports go here
import tweepy
# !pip3 install twint
#import twint
import json 
import datetime
#import geocoder
from tweepy import OAuthHandler
import csv

# %%
# load/read from file using JSON
secrets = json.loads(open("secrets_Samsung.json","r").read())

api_key = secrets['CONSUMER_KEY']
api_key_secret = secrets['CONSUMER_SECRET']
access_key = secrets['ACCESS_TOKEN_KEY']
access_key_secret = secrets['ACCESS_TOKEN_SECRET']


auth = OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_key, access_key_secret)
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

#change per brand
screen_name = "SamsungSupport"

# %%
import pandas as pd

# %%
import csv
csvFile = open('tweet_reply_Samsung.csv', 'w')
counter=0

csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q='@SamsungSupport',count=4000000,lang="en", tweet_mode='extended').items(4000):
    print (tweet.full_text)
    csvWriter.writerow([tweet.full_text.encode('utf-8')])
counter+=1

csvFile.close()
# Out:
# @SamsungSupport My Odyssey Plus display died mid-game and needs to be repaired, but I cannot find repair services here in Japan. How should I apply for repairs/support?
# @SamsungSupport @SamsungIndia @SamsungMobile visited service centre in Palwal Haryana India. centre asks 2%extra than the bill. Is it legally allowed even? @jagograhakjago can you please help?
# @SamsungSupport 4. On ALL my Samsung phones, the same bug in the YouTube app has not been solved for years! There is no such problem on phones of other brands! When will you finally fix it? https://t.co/maOAv3B1hK
# @SamsungSupport The Galaxy Watch3 was delivered with no watch band. Supposed to come with two. Was a gift for my husband’s birthday. Disappointing.
# RT @MatthewJGlenn: This will be the first of possibly endless days in which I say that @Samsung and also @SamsungUS and also @SamsungSuppor…
# @SamsungSupport why was my order cancelled? US106442540
# @SamsungIndia Now How can we Trust @Samsung and @SamsungSupport , See attached Screenshot, there are a lot more. https://t.co/RVvb8IEmuW
# @SamsungSupport I have received this communication on Samsung Members app. I am waiting for so long after sending the documents. After calling customer care, they say that I have called the wrong number for this issue and that I will definitely receive but dont know when. Very sad. Bad tactics.
# Hello @SamsungIndia @SamsungMobile @SamsungNewsIN @Samsung @SamsungUS @SamsungSupport ,
#
# Thanks for giving false hopes to your customers by doing false marketing, giving false offers and contests like #reviewandrating . No headphones received nor any communication from them. Sad https://t.co/RERZD7Z5AM
# daaaaangggggg i had thee nicest conversation with @SamsungSupport i just can't believe i got the chance to have a conversation with this guy rob who is the nicest!!!!!😭
# @SamsungSupport Ok just sent a message
# @SamsungSupport @paramountplus why no support on 2016 models? I bought mine (UN60KS800D) in late 2017 🙄 The TV can do 4K with Disney+, etc. works just fine with every other app.
# @SamsungSupport why doesn't paramount+ work on my 2018 TV
# @SamsungSupport Fix the battery life on the Watch 3.  It's terrible. #galaxywatch #samsung
# @SamsungSupport It’s not. The continuous effort to try and get me to repeat the steps I’ve taken several times is exhausting. I am confident you’re a nice person, but your employer is complete trash.
# @SamsungSupport @SamsungUS @Samsung The Q90r TV would be a lot nicer tv with the promised eArc update
# @SamsungSupport Again? Why? So you can tell me to kick rocks because there is nothing wrong with my fridge that won’t cool?
# @SamsungSupport I have a brand new microwave and every time I turn it on something on the right side of it sounds like a super fast fan spinning out of control and rubbing up against something as it spins.
# @SamsungSupport Sent you a dm
# @SamsungSupport I am sending DM and no response
# yo @SamsungSupport wtf did you do to my tv. Cant select my audio output with out it resetting. Mute Auto engages now. CANT TURN OFF CLOSED CAPTIONS like wtf did u do in that last update ok if you want me to buy a new tv nuke my old one but it sure wont be another Samsung 🙃
# @SamsungSupport Your customer service is the worst I've ever seen. I've been on hold or with an agent for 6 hours today and nothing is being done.
#
# DM with pls
# @SamsungSupport I did and u never respond
# RT @SamsungSupport: Have you heard of Private Share? Private Share is a new feature on the #GalaxyS21 series that helps to protect your dat…
# @SamsungSupport who told you this was a good idea https://t.co/K61NicLMYX
# So @SamsungSupport I called the number you provided in the private message at 230pm yesterday. Spoke to 2 people, neither could help. Was told someone would call me back within 24 hours. This has been over a month with no working fridge since we filed with the BBB. /1
# This will be the first of possibly endless days in which I say that @Samsung and also @SamsungUS and also @SamsungSupport are complete trash. Do not buy their products if you like having a working appliance or TV. @FridgeRecall
# @SamsungSupport I am extremely upset that our tv that is only 3 years old cannot get the paramount+ app!! I have always purchased Samsung TVs bc I thought they were the best. I’ll give another company a try with the next tv. This is not consumer friendly!
# @SamsungSupport I did DM you. 😊  Let me know what information you need.
# @SamsungSupport NO THANK YOU !
# @SamsungSupport Why would your unprofessional delivery service deliver a tv with a badly damaged box then you expect me to package it up, schedule a delivery and sit at home to wait on a freight truck to pick it up? The worst customer "service" I've ever experienced!
# So @SamsungUS @SamsungSupport reached out but is it just formality like an ai bot or they actually respond and resolve? https://t.co/jQjQm9CDeV
# @SamsungSupport banns me from their forum for describing the exact same problem that many are having with their 2018 and older 4K (and 8K) TV models. I have a so called 8K 75" Samsung TV in which the YouTube app both buffer and defaults to 360p picture quality for 4+ months ! WHY https://t.co/fgdwfhqW5Z
# What sucks more @SamsungUS refrigerators or their @SamsungSupport service? I think they compete in terms of quality.
# @SamsungSupport you guys are a ripe off
# @SamsungSupport I swear I’m either going to have to downgrade or something but your galaxy fold is so heavy, I’ve developed some type of pain in both of my hands from holding the phone.
# @SamsungSupport Done!
# @jiflwrh0pe @SamsungSupport It's ok 😭😭😭
# @chrryblossomjin @SamsungSupport awww sorry, then i don’t know what else to do😭😭😭
# @jiflwrh0pe @SamsungSupport It didn't work 😭😭😭😭
# @chrryblossomjin @SamsungSupport try it, i don’t have those buds, but sometimes that happens to the ones i own and i just forget the device and then it works
# @jiflwrh0pe @SamsungSupport No, I'll try that 😭
# @chrryblossomjin @SamsungSupport have you tried to forget device from your phone bluetooth settings?
# Y'aaaaaaaaall my bts samsung galaxy buds are doing weird stuff today, they freeze during the song and skip and makes my music sound like robot voices, I've already done a software update and reset them and it's still not fixed, what's going on 😭😭 @SamsungSupport
# And without my knowledge it has been returned as per latest status. Please help me expedite why it has been initiated for return without my nod. @Samsung @SamsungSupport
# @SamsungSupport From what I can tell online, this seems to be a known issue and there should be much better support for this problem.
#
# For $200, product should last more than 3 weeks and @BestBuySupport so should your support.
#
# Really sucks.
# @Bestbuy @SamsungSupport  Bought Galaxy Bud Pro on 14th, case doesn't charge any more. #Bestbuy store staff said they only support for 14 days so ppl have to buy extended warranty. Wondering if that's considered good customer service these days?
# Don't buy @Samsung appliances. We've been fighting with them for warranty repairs since January. Every call another story, another delay, another lie. The ticket number from @SamsungSupport after a bad product review doesn't exist in their system.
# @SamsungSupport I recently updated the firmware on my Galaxy Watch Active and now it depletes its battery within half a day despite not using anything. I reset the watch but the problem persists. Wearable app says Health is consuming the most battery. Is this a known issue?
# @SamsungSupport Hello, is there any update as to when @Verizon will be receiving more Galaxy S21 Ultra 512 gb models back in stock? I have received mix results from reaching out indicating it may never be restocked which sounds absurd to me on a phone that was just released.
# Ayo @SamsungSupport i sadly have other problem ;_;
# So I got my Galaxy Watch Active 2 more than a year ago
# And now, it's starting to disconnect and my phone (A51) is trying to reconnect but it just can't
# I've tried restarting both my phone and watch, resetting the watch and (1/2)
# PLEASE MAKE IT STOP.
# @VerizonSupport @nyalert This #WinterStormWatch from Feb16, with its time traveling time stamp, is still a problem. Just got it AGAIN. Good thing we're not being charged by the text. @fcc @SamsungSupport https://t.co/pu9eJ7DLWl
# RT @SamsungSupport: Not one, not two, not three... but SIX?!
#
# The #Galaxy21 Ultra puts a whole new spin on speed with Wi-Fi 6E. See the di…
# @SamsungSupport no shipping Info after 2 weeks of buying a product direct from your website.  Phone support just disconnects, website chat support just sends me on an endless loop asking for info.
# @SamsungSupport And oh. The part that you sleep with 50% battery and wake up to zero battery is icing in the cake. I have to charge the phone 2 -3x a day
# @SamsungSupport The screen everyday i have to restart because it keeps on glitching. Thats the part that annoys me the most. Samsung has asked me to do things to help but ut didnt at all. This is the 1st time this is happening to me after a decade of samsung phones mostly notes.
# @SamsonMFG @Samsung @SamsungMobileUS @SamsungSupport @SamsungUS the Galaxy S20 Ultra is one of the buggiest pieces of shite i've ever used.  I am never buying one of your phones again.
# @SamsungSupport hi I think my phone has a virus
# I have been a samsung user for more than 10 yrs.And after Using Samsung Note 20 ultra? this is the first time for me ever that I am considering switching to Iphone.Seriously! battery runs out fast even when not in use.The phone glitches everyday.  @SamsungMobile @SamsungSupport
# @SamsungSupport I have one of your broken French door refrigerators with ice maker issues and a large rust spot in the rear
# @SamsungSupport I’d like to be able to use the security features of my T7 Portable SSD, this is a crucial part of software not a feature update.
# @SamsungSupport When will we  get Portable SSD Software for M1 Macs?
# @SamsungSupport hi there was wondering if there is an estimate as to when more S21 ultra 512gb phantom navy will be for sale on page again?
# @MHess81 @SamsungMobileUS @SamsungSupport OMG! Tiff and I have gotten those, too!
# Hello @SamsungSupport , I tried accessing Secure Folder on my mobile  device but I was denied access. Below is attached screenshot of the error message it's pops up. My device is Samsung S8+. Thanks as await your response. https://t.co/h2sXoorLKk
# @SamsungMobileSA This is how pathetic @SamsungSA @SamsungSupport is. 6 weeks turned to 5 months all I get is "Dm us so we follow up" then a dead end. Calling is also full of empty promises  scam https://t.co/ZlcuWppmtc
# @SamsungMobile @samsungID @SamsungSupport gonna give props to the newest update, cleaner transitions and animations, feels fluid, i also think that the high refresh rate is also smoother (consistent between switching apps, etc). Feels new!
# @SamsungMobile @SamsungIndia @SamsungSupport We had placed a service request for our warranty due to the hang in the device when camera is opened and still there's no response even after 4 days of request approval. What's the status.. I'm uploading the supporting documents below https://t.co/PMgBBTjLLP
# @SamsungIndia @SamsungUS @Samsung @SamsungSupport
#
# Worst services and product ever in Samsung india..
#
# Spark in oven within 10 months and no one ready to solve issue..
#
# Not recommended at all @SamsungMobile products...
# @SamsungIndia @amazonIN @Flipkart #SAMSUNG PLZ REPLACE OUR DEFECTIVE FRIDGE NOT INTERESTED IN DEPRECIATION AMOUNT,bought fridge 4m VIJAY SALE'S for 37500/,10 yr comp warranty within 3 years unrepairable, refunding RS 26000/+
# Ibrahim Retiwala 9892952434
# @SamsungIndia @Samsung
# @SamsungSupport @VijaySales #SAMSUNG
# @SamsungUS #SAMSUNG PLZ REPLACE OUR DEFECTIVE FRIDGE NOT INTERESTED IN DEPRECIATION AMOUNT,bought fridge 4m VIJAY SALE'S for 37500/,10 yr comp warranty within 3 years unrepairable, refunding RS 26000/+
# Ibrahim Retiwala 9892952434
# @SamsungIndia @Samsung
# @SamsungSupport @VijaySales #SAMSUNG
# @SamsungSupport #SAMSUNG PLZ REPLACE OUR DEFECTIVE FRIDGE NOT INTERESTED IN DEPRECIATION AMOUNT,bought fridge 4m VIJAY SALE'S for 37500/,10 yr comp warranty within 3 years unrepairable, refunding RS 26000/+
# Ibrahim Retiwala 9892952434
# @SamsungIndia @Samsung
# @SamsungSupport @VijaySales #SAMSUNG
# @SamsungUS #SAMSUNG PLZ REPLACE OUR DEFECTIVE FRIDGE NOT INTERESTED IN DEPRECIATION AMOUNT,bought fridge 4m VIJAY SALE'S for 37500/,10 yr comp warranty within 3 years unrepairable, refunding RS 26000/+
# Ibrahim Retiwala 9892952434
# @SamsungIndia @Samsung
# @SamsungSupport @VijaySales #SAMSUNG
# @KalravShah7 @SamsungIndia @Samsung @SamsungSupport #SAMSUNG PLZ REPLACE OUR DEFECTIVE FRIDGE NOT INTERESTED IN DEPRECIATION AMOUNT,bought fridge 4m VIJAY SALE'S for 37500/,10 yr comp warranty within 3 years unrepairable, refunding RS 26000/+
# Ibrahim Retiwala 9892952434
# @SamsungIndia @Samsung
# @SamsungSupport @VijaySales #SAMSUNG
# @KalravShah7 @SamsungIndia @Samsung @SamsungSupport #SAMSUNG PLZ REPLACE OUR DEFECTIVE FRIDGE NOT INTERESTED IN DEPRECIATION AMOUNT,bought fridge 4m VIJAY SALE'S for 37500/,10 yr comp warranty within 3 years unrepairable, refunding RS 26.+ K
# Ibrahim Retiwala 9892952434
# @SamsungIndia @Samsung
# @SamsungSupport @VijaySales #SAMSUNG
# RT @KalravShah7: There is an issue with my Fridge-&amp; I am having a hard time getting it fixed after paying Hefty amount &amp; spending time chas…
# @SamsungSupport I just did
# Dang @SamsungSupport, have you ever had other reports of your microwaves being unable to be rendered inert? https://t.co/EEUQdeyW0L
# RT @MHess81: Omg that is so gross @SamsungMobileUS @SamsungSupport should be ashamed allowing this!  There are minors on samsung health!!
# Omg that is so gross @SamsungMobileUS @SamsungSupport should be ashamed allowing this!  There are minors on samsung health!! https://t.co/MRPzkiwIHx
# @SamsungSupport I don't have another one at the moment.
# @SamsungSupport Yes I am. Not the box but the cord is still the same.
# @SamsungSupport Why isn't my Samsung Galaxy a20 charging like it suppose to? I usually put my phone on the charge at 15%. Never had a problem. But for 2 days straight, when I put my phone on the charger at 15% or below, it drains my battery very quickly. Help?
# @SamsungSupport I purchased a galaxy s21 ultra recently, customer support repeatedly denied my price match request, stating doesn't fall under their policy if it exceeds 15 day return window, however clearly I can still return the product, per the updated return policy of 60 days
# @FedEx @FedExHelp @SamsungMobileUS @SamsungSupport #GalaxyS21Ultra  thanks for my #GalaxyS21Ultra DAMEGE 😡😡😡😡 https://t.co/lJeGJlBufr
# @SamsungSupport
#
# An agent of yours caused me to miss out on the $160 dollar instant credit for the S21 Ultra. I called in and was told they would make up for that, but 4 days later I still don't have the credit I was promised. Can I please get some help?
# @SamsungSupport It's not necessary. This was the last straw for me.  Your updates are horrific.  Stay safe.
# @SamsungSupport Why do your updates always mess up my phone.  Everytime this happens you literally break the law. I bought it as was and you change it without my consent. I either gain something I don't want or lose something I needed.  After 15 years I'm leaving samsung.
# @SamsungSupport please help! Brand new Note 20 Ultra, not getting any audible notifications for calendar or messages.
# @rettafie @SamsungSupport Did you ever get an answer? Just got this phone and no notifications for calendar OR messages. Have tried everything.
# @SamsungSupport Okay, thank you.
# @SamsungSupport If you don’t want to have to defrost your refrigerator every other month don’t buy a @SamsungUS @ConsumerReports @HomeDepot @Lowes https://t.co/pLOxuez8XV
# @SamsungSupport Will you be restocking the Note 20 Ultra in mystic bronze for Tmobile?
# @SamsungSupport Just want to say having customers change the position of the exhaust fan on your over the stove microwaves is the f*#%ing stupidest things I have ever encountered!! Total BS!
# @SamsungSupport the Home Button and Source buttons stopped working on my Samsung remote model bn59-01315a. All other buttons work. I cannot access to menu or settings because of this. I changed the batteries and tried holding down the home button. Nothing worked. How do I fix it?
# @SamsungSupport Can you help?
# @PeacockTVCare @SamsungSupport I hope this is true! Lol
# So @SamsungSupport are we actually on for March 13 delivery date now or should we both assume that’s not happening either?
# @SamsungSupport hey your safety team is so not helpful and we have an issue and they don’t want to resolve it. Can someone please help?
# @SamsungMobileUS @SamsungSupport @Samsung what do I have to do to get my dryer? 5 times you reschedule? FIVE? And then have the gall to tell me that twice was my fault? Yes, because you people couldn’t keep your first three appointments.
# @SamsungSupport @SamsungUS You have the WORST Customer Service/Tech Support on the planet. I have spent 45 minutes with CC/TS only to be told to call the same number I called before I was transferred to CC/TS.  Stick to phones. Everything else is crap.
# Okay but imagine if  @SamsungSupport made a red galaxy z flip😳
# @askJoyMarketing @SamsungSupport You too!! 🥰
# Just ordered @peacockTV but now just realized I can’t get the app on my @SamsungSupport smart tv. Can you both pull up your big boy pants and get your silly disagreement solved?
# @ashleecloud @SamsungSupport Ugh so frustrating. Definitely not something you want to deal with, and definitely not during a pandemic! Sending positive fixy vibes your way!
# @SamsungSupport impossible to get through to get support! Was given a phone with striped screws and can't fix a $29 cracked screen. Why do I have to pay more for a damaged phone?
# .@SamsungSupport My French door #Samsung fridge 6 years old and the freezer stopped working. Waranty expired and repairs would run about $1000. Talked to 5 Samsung reps to see if I could get a replacement at a decent price no luck. No more Samsung product for me. https://t.co/1clRV8M0gX
# @askJoyMarketing @SamsungSupport Exactly!
#
# We bought ALL of our kitchen appliances from Samsung and I will never do it again. We've had our stove "fixed" 3 times &amp; it's still not working correctly &amp; now our fridge. Nope. Never again.
# @ashleecloud @SamsungSupport Right? Oh why don't we send a tech over so you can give them more of your money to fix our crappy product. I was watching a YouTube video on how to do diagnostic on the Samsung washer and they literally said they break a lot!
# Please tell me something other than to DM you or call you because now I've spent over 2 hours combined doing that &amp; it hasn't been fruitful. @SamsungSupport https://t.co/qI1E8YD02w
# @askJoyMarketing @SamsungSupport I'm getting the same crappy service.
#
# And then you dm them and have to wait and wait for a reply. I can't hang out on Twitter all day for you, Samsung. I just want the products that I've paid you THOUSANDS of dollars for to work.
# @SamsungSupport
# Odyssey G9 monitor, does it allow for a Mac and PC to display simultaneously at full resolution? Meaning will both computers fill each side with both using DP ports?
# MacBook pro 15, 2017 Radeon pro 560
# Lenovo ThinkPad T14s
# @SamsungSupport my s21 ultra is not sending mms, what do I do?
# @SamsungSupport Wait, are you telling me I have to connect yet another device, just to get this app to stream? That’s absolutely ridiculous. The easiest thing to do is just cancel my subscription. @paramountplus @SamsungSupport @SamsungUS   It’s 2021. The app should be available
# @SamsungSupport I contacted support via text &amp; they kept telling me sorry for delay in responding. After 1 hr they send me generic link which I had found in 2 minutes of searching. Seems like the person on your end probably took lunch instead of trying to help me. Poor service!
# @SamsungSupport I’m aware of this. The new app, that replaces it, is not available on my TV, which is new. What’s the solution @paramountplus @SamsungSupport ?
# @SamsungSupport @SamsungSupport @paramountplus  If the tv isn’t the issue, then the app is. Im paying for a product that I don’t have access to and I’d like to have a resolution. Thanks
# @SamsungSupport Everything I find says it’s a 2020 model  so why isn’t this app available?
# @SamsungSupport UN43TU7000FXZA is the model. Purchased in 2020
# @SamsungSupport I already did that, as this email is a reply from "Samsung E-Commerce" after the phone team could not figure out why my order was canceled. They clearly do not have the right tools to address it as they just said "we won't process orders at this address."
# @SamsungSupport I’ve had this tv for less than three years. I have other apps in it as well.
# @paramountplus why isn’t the app available for Samsung TV @SamsungSupport ?  We had the CBS app until today  and no longer have access to the subscription we’re paying for.
# @SamsungSupport because there is no @TwitchSupport on your TV devices?
# Is this a fucking joke? I live in an apartment building with hundreds of other apartments and because some other resident fucked up, you block orders for the entire fucking complex? @SamsungSupport, you need to fix your fucking order system. https://t.co/0OoCS1ZOJZ
# @SamsungSupport I live in AZ. How do I get my appointments after DST to not adjust forward an hour?
# Samsung is on my shit list @SamsungSupport
# RT @megloops: How I spent my morning...
# Making #Borscht
#
# BTW @SamsungSupport has really messed up their update to the Camera Story making.…
# @SamsungSupport Hello Samsung SSD Customer Service! Are you here? Because you are not online or answering the phone
# @SamsungSupport Hello Samsung SSD Customer Service! Are you here? Because you are not online or answering the phone
# @SamsungSupport This still has not been resolved
# RT @MonsieurOblong: Is there a human on this planet with a Samsung icemaker that actually fucking works? Who the fuck thought putting an ic…
# RT @KeKeNicKi: Just your daily reminder that @Samsung @SamsungUS @SamsungSupport is selling defective products to consumers and refuse to r…
# RT @KeKeNicKi: Just your daily reminder that @Samsung @SamsungUS @SamsungSupport is selling defective products to consumers and refuse to r…
# @SamsungHealth @SamsungSupport Jungle March won't update with my step count for today - "no response from service. Please try again later" error message at the bottom of the screen. Samsung S9 Plus #samsunghealth #shealth #junglemarch https://t.co/cqEk03dxlc
# Hi, I just received the galaxy watch 3, But I can not find any band in the package although I had ordered one!
# @SamsungSupport
# @SamsungUS
# RT @KalravShah7: There is an issue with my Fridge-&amp; I am having a hard time getting it fixed after paying Hefty amount &amp; spending time chas…
# There is an issue with my Fridge-&amp; I am having a hard time getting it fixed after paying Hefty amount &amp; spending time chasing you guys. This is a horrible customer care experience! Plz get in touch with me ASAP and solve this urgently. @SamsungIndia @Samsung @SamsungSupport
# Just your daily reminder that @Samsung @SamsungUS @SamsungSupport is selling defective products to consumers and refuse to recall. Do NOT buy a Samsung refrigerator unless you don't like ice and safe food temps 🤷‍♀️
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung why r u crying 🥺
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung why r u crying over a teenager telling u to d word after being misogynistic for three hours on end
# Thank you @SamsungSupport for your support with by TV ticket. I got my refund and I upgraded to 82” Samsung TV. Thanks for all your help https://t.co/zpL5gOtAXU
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung *male*
# @NYUPHOBIA @doiescents @eternaljeno @SamsungSupport @Samsung *often*
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung (often male)
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung if u reply with simp that means you agree that women are superior
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung new vocabulary unlocked ‼️🥺🥺
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung baby learned a new word 😩🙏
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung hey , if i give you my paypall and i promise to send u sandwichs every day , would u send me some money?
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung y do u wanna have the last word so bad r u really that insecure
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung bitch make more
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung oh cuz my friend mentioned u were a simp so now you're trying to hide it by calling us simps lmfaoo . go get a job
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung thats why ur useless literally what do u do
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung ok ill let u know how it goes !!
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung go n make money !!
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung ?????? are u 5 . can you make coherent sentences???
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung just say ur useless n go 🤗
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung your sentences are so simple. you don't even care to make an actual point anymore. perhaps go back to work? provide for your family?
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung bitch what r u saying
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung yes what 😭 are you agreeing your memory is so low that you can't even remember something you tweeted literally 20 seconds ago ???
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung bestie if we could change we would
# @doiescents @KENTASZN @eternaljeno @SamsungSupport @Samsung men wallets !
# @NYUPHOBIA @KENTASZN @eternaljeno @SamsungSupport @Samsung men stupid !
# @doiescents @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung I didn’t?
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung why would u say hes a racist if ur trump2020
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung is that your age? no wonder
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung its 2021 my dude
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung anyways i wanna know more abt u 🙏 r u a trump supporter
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung okay , then no one else has to agree with u thinking women are dumb. you never provide evidence so :/ better luck next time comerade
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung correlation??? i knew you were lying dude hahahah imagine being so weak you have to lie about being stronger than women. pathetic 🤣
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung u dont seem to b like competing in the olympics or wtv competitions u have
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung proof? men are always lying. if you don't have proof then i'll just assume you made it up.
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung i bet shes better
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung i bet it is 💯
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung you're weird, admit women are better than u . if she ever saw your ass she would beat u up record time 😂😂 weak man
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung 😭😭😭😭 so u hate all women unless theyre wrestlers or wtv bcs then they can like beat u up or smt
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung yeah must b horrible to b stuck in a marriage with a manchild who cant make his own food n relied on his mom until his 30s
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung omg , is it because you're scared she'll beat you up?
# @NYUPHOBIA @KENTASZN @eternaljeno @SamsungSupport @Samsung n what abt ur wife ??
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung wait i have a question though. what about the woman in your header? is she stink poo poo or is she one of the lads?
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung it seems like u like my idea, effective immediately then
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung damn hope she gets well soon 😔🙏
# @NYUPHOBIA @doiescents @eternaljeno @SamsungSupport @Samsung BRUUUH 😂
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung what 😂😂😂😂
# @KENTASZN @doiescents @eternaljeno @SamsungSupport @Samsung you do know we can collect male sperm from the de*d men and keep reproducing. then we'll let them live to the same age and keep doing the same thing. we only need u foor a short ammount of time. then all the sandwichs in the world are ours. are you jealous?
# @KENTASZN @NYUPHOBIA @eternaljeno @SamsungSupport @Samsung ur just jealous we get more girls than u 😔
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung exactly !!! earth doesnt need us n i think its time to end the human race for good
# @KENTASZN @eternaljeno @doiescents @SamsungSupport @Samsung it's fine it only happens for a good minute , at least i dont have to live through my whole life like you 🥺i hope you feel better soon 🙏
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung no i think we should just k!ll off all men and society would be perfect
# @NYUPHOBIA @eternaljeno @doiescents @SamsungSupport @Samsung Sorry to hear that 🙏
# @KENTASZN @eternaljeno @doiescents @SamsungSupport @Samsung me when i dont get enough female attention 😩
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung why r u bragging
# @KENTASZN @doiescents @NYUPHOBIA @SamsungSupport @Samsung me when im irrelevant
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung show me 👍🏼
# @KENTASZN @eternaljeno @doiescents @SamsungSupport @Samsung A KPOP SEXUAL AJAHAHHAAH youre so funny, did anyone ever tell you that? if so , they were lying ☺️
# @KENTASZN @doiescents @NYUPHOBIA @SamsungSupport @Samsung Not reading all that because a sexist wrote it so it has no logic behind it
# @eternaljeno @doiescents @NYUPHOBIA @SamsungSupport @Samsung Not reading all that because a kpop sexual wrote it so it has no logic behind it
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung damn seems kinda sus 🙏 u got any proof
# @KENTASZN @doiescents @NYUPHOBIA @SamsungSupport @Samsung Not reading all that because a man in pain wrote it so it has no logic behind it
# @eternaljeno @doiescents @NYUPHOBIA @SamsungSupport @Samsung Not reading all that because a woman wrote it so it has no logic behind it
# @eternaljeno @doiescents @NYUPHOBIA @SamsungSupport @Samsung @SamsungMobileUS Ok dishwasher. @SamsungSupport
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung is https://t.co/z6seA9YFgE ur only friend
# @KENTASZN @doiescents @NYUPHOBIA @SamsungSupport @Samsung Not reading all that because a man wrote it so it has no logic behind it
# @KENTASZN @doiescents @NYUPHOBIA @SamsungSupport @Samsung @SamsungMobileUS ok wallet
# @eternaljeno @doiescents @NYUPHOBIA @SamsungSupport @Samsung @SamsungMobileUS Ok dishwasher
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung @SamsungMobileUS mf im not urs
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung @SamsungMobileUS why r u tagging samsung mobile 😭😭😭😭
# @doiescents @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung I do. @SamsungMobileUS @SamsungSupport NEED YOUR HELP WITH MY DISHWASHER ASAP
# @KENTASZN @NYUPHOBIA @doiescents @SamsungSupport @Samsung aww thats cute, that means we r at least worth några tusen🥺🥺
# @KENTASZN @eternaljeno @NYUPHOBIA @SamsungSupport @Samsung who tf has samsung dishwashers
# @eternaljeno @NYUPHOBIA @doiescents Ayo @SamsungSupport GET YOUR DISHWASHER. ITS MALFUNCTIONING. @SAMSUNG
# @SamsungSupport Thank you. I couldnt find it with the ones listed so I just ordered one from someone else on amazon 🤞🏾
# 2 months into the phone and it opens (Galaxy Note 10 + @SamsungIndia @SamsungMobile @SamsungMobileUS @Samsung @SamsungSupport @MKBHD @Dave2D @TechnicalGuruji https://t.co/1TnidzaHS7
# @SamsungCO @SamsungIndia @SamsungMobile @SamsungSupport @SamsungUS
# Resolve the issue as soon as possible
# It's too much delayed
# Still no proper service https://t.co/3o6QOV48yZ
# @SamsungMobile @SamsungIndia @SamsungMobileUS @SamsungSupport @SamsungUS @SamsungSupport I bought samsung S20fe and encountering heat issue and battery issue. Its 14th day and service Center’s are not accepting this, which is very inappropriate from samsung service centre’s
# RT @malibu_g4g4: Always a sign when the stupid thing is grinding. Time chisel out the ice from around the ice maker unit. What a piece of s…
# would you please reply @SamsungMobile @SamsungIndia @Samsung @SamsungSupport
# Hello @SamsungIndia , i have Samsung Galaxy m31 phone. Two weeks before I updated my phone. After that the battery of the phone doesn't stay for long hours as it is of 6000mah .Please help me out of this..
# #Samsung @SamsungIndia @SamsungSupport
# My s pen broke tonight @SamsungSupport are these after market ones on Amazon trustworthy? Because the Samsung site does not sell replacement ones for a Note 8!! I don't want no problems!
# Can change the display ofYou can change my mobile display without moneyI do not have much money in my mobileI hope you can do so much as a human being. @SamsungMobile @SamsungSupport @SamsungSC https://t.co/D0u9e5a1dV
# @malibu_g4g4 @SamsungUS @FridgeRecall @SamsungSupport It's interesting how SAMSUNG offer depreciation amount of faulty product 34/5/56/71 % offering me of 37.5 k fridge , amazing from where they bring this figure , Ibrahim Retiwala +919892952434 Samsung sufferer.
# RT @malibu_g4g4: Always a sign when the stupid thing is grinding. Time chisel out the ice from around the ice maker unit. What a piece of s…
# Hey @SamsungSupport why does my tv keep on getting disconnected to the wifi network? Can you help?
# @KeKeNicKi @FridgeRecall @LauraSue14 @SamsungUS @SamsungSupport @Samsung It's interesting how SAMSUNG offer depreciation amount of faulty product 34/5/56/71 % offering me of 37.5 k fridge , amazing from where they bring this figure , Ibrahim Retiwala +919892952434 Samsung sufferer.
# RT @KeKeNicKi: @FridgeRecall @LauraSue14 @SamsungUS @SamsungSupport @Samsung Yep! I didn't know there was a Twitter page also, I'm just try…
# @di_army7 @SamsungMobile @SamsungMobileUS @SamsungSupport Beggar
# RT @SamsungSupport: Last January, we had our 29th "Unpacked" event; unveiling the #GalaxyS21 family of flagship devices, and multiple other…
# @SamsungSupport Fixed it
# Is there a human on this planet with a Samsung icemaker that actually fucking works? Who the fuck thought putting an icemaker inside of a fridge would work? I’ve force defrosted the thing more times than I can count, replaced the entire icemaker once.  @SamsungUS @SamsungSupport
# @SamsungSupport Samsung customer service was no help at all. They're telling me I got to make it as a new account. But all my credit cards are already on my Samsung account, so what do I do?
# RT @SamsungSupport: Last January, we had our 29th "Unpacked" event; unveiling the #GalaxyS21 family of flagship devices, and multiple other…
# @SamsungSupport  I need help!!!!
# @SamsungSupport how can I fix this random issue? It happens to every app that has a pop out feature. You can see me drag it to the top, but as soon as I let go of flies off the screen to the bottom. https://t.co/vrJjpj71Pq
# Now 15 days passed and no delivery. Unbelievable @SamsungMobile @SamsungSupport @SamsungMobileUS @SamsungUS @Samsung #inconsiderate #poorcustomerservice #badbusiness https://t.co/fLgV5jwHSB
# @SamsungSupport No, I’m good, thanks
# @SamsungSupport I can't for the life of me find the spare ear tips that came with my Galaxy Buds Pro - is there anywhere I can order a replacement set?
# @SamsungSupport where can I find Samsung own info/resources on how to recover deleted files of a Galaxy Note 10.1?
# @samsung @SamsungSupport @SamsungTV please make updating apps easier. Or better yet fix the damn auto update feature
# @creativedodger @SamsungSupport And same goes with note 20 5g in usa
# @SamsungSupport Bought a Samsung Galaxy Watch Active2 watch in August 2020. There are two black semi-circle areas at the top of screen. Seems to be a issue with this device. Tried restarting and resetting. Neither works. @ATT @attmobilecenter @ATTMobilePR will not help.
# @SamsungSupport Thanks
# @creativedodger @SamsungSupport Thnks
# RT @KeKeNicKi: @FridgeRecall @LauraSue14 @SamsungUS @SamsungSupport @Samsung Yep! I didn't know there was a Twitter page also, I'm just try…
# @SamsungIndia This is still pending.... guess #samsung has gone #deaf
# Never expected such a pathetic after sales service from @SamsungIndia that too for flagship #SamsungGalaxyS21Ultra customer @SamsungNewsIN @SamsungMobile @SamsungSuomi @SamsungSupport @SamsungSupport
# My @Samsung @SamsungSupport saga is over. I finally have my refund after just 36 days. Samantha on their social media team gets an A+ for taking care of me, the rest of the process, well it was a nice relationship while it lasted, but looks like I'm an @LGUS  monitor guy now. https://t.co/niBT0T95gL
# @crmsaasguy @FridgeRecall @SamsungSupport It's interesting how SAMSUNG offer depreciation amount of faulty product 34/5/56/71 % offering me of 37.5 k fridge , amazing from where they bring this figure , Ibrahim Retiwala +919892952434 Samsung sufferer.
# RT @crmsaasguy: I am truly trying to become a person more #thankful and not complain but when I have to deal w/companies that create/sell s…
# @Finderat97 @FridgeRecall @Samsung @SamsungusaUSA @SamsungSupport @SamsungCareSA @Samsungcare01 It's interesting how SAMSUNG offer depreciation amount of faulty product 34/5/56/71 % offering me of 37.5 k fridge , amazing from where they bring this figure , Ibrahim Retiwala +919892952434 Samsung sufferer.
# RT @Finderat97: Hey @Samsung Replace my design defect refrigerator!  It’s documented that it’s a design defect NOT a warranty issue!@Samsun…
# @KeKeNicKi @FridgeRecall @SamsungUS @SamsungSupport @Samsung It's interesting how SAMSUNG offer depreciation amount of faulty product 34/5/56/71 % offering me of 37.5 k fridge , amazing from where they bring this figure , Ibrahim Retiwala +919892952434 Samsung sufferer.
# Hello @SamsungMobileUS @SamsungSupport "order #US054285072 is delayed more than 30 days.
# If you still want the order, no action is required. You may also cancel your order." That's the response for an order placed Feb 04.
# @LauraSue14 @FridgeRecall @SamsungUS @SamsungSupport @Samsung I've been a part of the group since November. I followed all the steps and Samsung is trying to give me a "pro rated refund" that I refuse to accept because I know they can do better than what they're offering me. Next step is small claims court.
# RT @KeKeNicKi: If you have a Samsung refrigerator that doesn't keep safe temps or has ice maker issues DM me. I've got more info on how @Sa…
# @FridgeRecall @LauraSue14 @SamsungUS @SamsungSupport @Samsung Yep! I didn't know there was a Twitter page also, I'm just trying to get my refund by blowing up Samsung's social media accounts
# @LauraSue14 @KeKeNicKi @SamsungUS @SamsungSupport @Samsung You mean the group linked  in my profile?
# RT @malibu_g4g4: Always a sign when the stupid thing is grinding. Time chisel out the ice from around the ice maker unit. What a piece of s…
# RT @malibu_g4g4: My most fun Sunday morning ritual. Thanks @SamsungUS for your shit products. #samsungsucks @FridgeRecall @SamsungSupport h…
# @KeKeNicKi @FridgeRecall @SamsungUS @SamsungSupport @Samsung There is a huge group I follow on FB with all kinds of information about filing claims with the better business bureau, etc. I was made an offer on our fridge (prorated refund) after two repairs. Fan dead again (probably iced up again). Waiting for the paperwork. https://t.co/QCSGlCFBiv
# RT @elizabeth1220: @SamsungSupport So for anyone following, basically they said my case is being handled by a “higher support team” (who I…
# RT @mdamon34: @SamsungSupport @SamsungUS hi Samsung still waiting for you to fix my refrigerator defect. It is a well documented design def…
# RT @Finderat97: Hey @Samsung Replace my design defect refrigerator!  It’s documented that it’s a design defect NOT a warranty issue!@Samsun…
# RT @crmsaasguy: I am truly trying to become a person more #thankful and not complain but when I have to deal w/companies that create/sell s…
# RT @KeKeNicKi: If you have a Samsung refrigerator that doesn't keep safe temps or has ice maker issues DM me. I've got more info on how @Sa…
# @di_army7 @SamsungMobile @SamsungMobileUS @SamsungSupport I just saw! He's definitely gonna get sent a new one now 😂
# @SamsungMobile Hello @SamsungMobileUS @SamsungSupport your ambassador Jungkook's phone got broken and he even taped it, could you please get him a new one? 😻💜💜💜💜 https://t.co/qtEoxWMfxs
# @SamsungMobile Hello @SamsungMobileUS @SamsungSupport your ambassador Jungkook's phone got broken and he even taped it, could you please get him a new one?😻😻😻 https://t.co/IH88fat5cu
# @ThisBoyWithLuv1 @SamsungMobile @SamsungMobileUS @SamsungSupport thought*
# @ThisBoyWithLuv1 @SamsungMobile @SamsungMobileUS @SamsungSupport the last post on @SamsungMobile is filled with armys comments asking samsung to get him a new phone, I'm dying, how have I not think about this before? :D
# @di_army7 @SamsungMobile @SamsungMobileUS @SamsungSupport Ha! I was thinking the same! 😂
# Hello @SamsungMobile @SamsungMobileUS @SamsungSupport your ambassador
# Jungkook's phone got broken and he even taped it, could you please get him a new one? 🙂 https://t.co/rr6yC2FUP1
# I finally received my device from Samsung. 29 days total as opposed to the promised 7 day turn around. Only 9 days of the delay were a result of weather. They reversed the charges &amp; did the repair free of charge for my troubles. @SamsungSupport
# @SamsungSupport Yes, I received it on Friday. Thank you
# Always a sign when the stupid thing is grinding. Time chisel out the ice from around the ice maker unit. What a piece of shit product and company @SamsungUS is. @FridgeRecall @SamsungSupport https://t.co/T464nOe0uJ
# My most fun Sunday morning ritual. Thanks @SamsungUS for your shit products. #samsungsucks @FridgeRecall @SamsungSupport https://t.co/ibKrHwqndk
# @SamsungSupport How do I get support for getting my Active 2 (US) to work with non-US purchased Samsung mobile? Not getting a response from your email team.
# @SamsungSupport my couple years old Samsung tv volume gets stuck. Won’t up or down a few rocks. Very frustrating. Tried resetting tv to changing batteries. Nothing works permanently. Very frustrating for a newer tv
# @SamsungSupport pre-ordered S21 and got the credit, but the Samsung store has been sold out of anything I'd want to spend it on for over a month... When will you restock or extend expiration of code
# @SamsungSupport How do I activate my samsung smart cover?
# @SamsungSupport After waiting 6 and a half weeks for you to ship my new S21 Ultra you send my order in 3 shipments (so far) and you send my phone case 2nd day air. But my phone with FedEx ground? I'm very disappointed with the service and support I've recieved from you this time
# @SamsungSupport Dear Samsung, there's a website called samsungpower(.)com. Is that an official web by Samsung or just a scam site? Please check immediately, thank you.
# RT @AYAZYKHAN2: Didn't Responding to Grievances and Speaking Rudely with the Said Lady who is a Regular Customer. @jagograhakjago @nch14404…
# @SamsungSupport I’m in the uk and my freezer has stopped working and my food has defrosted please help I have a 10 year wannaty on the compressor
# @SamsungIndia @SamsungSupport This error after di-registration and while registering new fingureprints https://t.co/GuenfVPzyr
# @FedExHelp @SamsungSupport Should I be concerned that my trade-in that I shipped out at a Fedex Ship Center doesn't have an active tracking #?
# @YouTube @Google @SamsungTV @SamsungSupport please come up with a agreement for YouTube apps for older TV'S like the UN50EH5300
# @SamsungSupport About yourself
# @SamsungSupport I bought 1 samsung G998U1 today I have no e sim and no more in arabic tukce, put an end to this disgrace samsung
# RT @TechFreaker: Retweet my issue friends @C4ETech @TamilTechOffici @Geekytamizha_ @TechBossIndia @RealTamilSelvan @SamsungIndia @SamsungSu…
# RT @TechFreaker: Retweet my issue friends @C4ETech @TamilTechOffici @Geekytamizha_ @TechBossIndia @RealTamilSelvan @SamsungIndia @SamsungSu…
# Yo @SamsungMobileUS @SamsungSupport your update got my phone buffering like it's 05 n this y im considering @Apple 🤬
# @SamsungSupport  you fucking wear me and 40 k plus people out just do the right thing and stand by your product
# Retweet my issue friends @C4ETech @TamilTechOffici @Geekytamizha_ @TechBossIndia @RealTamilSelvan @SamsungIndia @SamsungSupport @loud_oli @geekyranjit @MKBHD @Mrwhosetheboss @yabhishekhd @chat_station @MadhavSheth1 @manukumarjain @TechnologyJock @techtamizha  @TRAI @CMOTamilNadu https://t.co/itwB1pXdwn
# Hey @MKBHD any idea why samsung won't allow Pro mode with other lenses? wide and tele? Doesn't make sense to me. @SamsungSupport ? @SamsungMobile ?
# @SamsungSupport So for anyone following, basically they said my case is being handled by a “higher support team” (who I can not get a hold of). Never buy a Samsung if you want an ice machine and fridge that work!
# @SamsungMobileUS  @SamsungSupport  - Extremely frustrated with your false advertising of #S21Ultra 5G Unlocked that it supports eSIM when your tech support confirms that it doesn't support yet. :(
# @TorreyShirk That's definitely odd! In that case, we suggest reaching out to @SamsungSupport for further troubleshooting.
# RT @speakanytime: @SamsungIndia @SamsungIndia @SamsungMobile @SamsungUS @SamsungMobileUS false claim, #fraud commitment &amp; #worst customer s…
# @SamsungMobileUS @SamsungMobile @Verizon @SamsungSupport The fingerprint scanner on the S20 and Note 20 Ultra SUCK!!!!!!  GO BACK TO THE S9 STYLE with the scanner by the camera.  Never failed https://t.co/xCiXcY0rAZ
# RT @abanyazz: @SamsungSupport And just to clarify, if my phone is compatible, I should be able to find the Health Monitor app within the ga…
# @SamsungSupport @SamsungMobileUS How do you "cancel" a Service Request without any notes about why cancellation, and just a message sending un-repaired device back .. What kind of customer service is that #badcustomerservice
# @SamsungSupport @SamsungSupport  I already had multiple calls on the same number with two different tickets, I reached here after multiple failed attempts to get my complaint resolved #badcustomerservice
# @SamsungSupport is anyone around to help?
# Hey @SamsungSupport I was given this email to contact customer support but it saying it is an invalid email Willistine.s@sea.samsung.com Who do I contact as Stacey is out of the office for a week and our fridge is still broken? Repair guy today did absolutely nothing/no answers.
# @IBrock_IDiesel @SamsungMobileUS @SamsungMobile @Samsung @SamsungUS @SamsungSupport That's what friends do. Ride or Die. 🤜
# @SamsungSupport From plastic to... plastic.
# We gotta let @SamsungSupport @SamsungUS @TheCW know! The demands are real! Calling on the Superheroes @cwsupermanlois @CW_TheFlash @TheCWSupergirl https://t.co/xcNQF9eFUm
# RT @SamsungSupport: @IBrock_IDiesel Thank you for bringing this to our attention, Brock. Please send us a DM so that we may look into this…
# @SamsungSupport how do i enable 120hz on ps5 on the samsung series 7 tv
# @mkostial05 @SamsungMobileUS @SamsungMobile @Samsung @SamsungUS @SamsungSupport Thanks for this man... A gif can't express how much I appreciate it
# @SamsungSupport Owned most of em. Now S21
# @SamsungSupport Galaxy Series is awesome.  Samsung Access Program is not. Samsung E-Commerce Customer Service is not.
# @SamsungSupport Those were the times.
# @SamsungSupport crazy
# ...
# @vegaslux12 @SamsungSupport Are they sending it to the right address though?  The last 2 packages were sent to my old address, a 3 hour commute (1.5 hours one way).  They appear to be on top of their game the last month or two (yes that's sarcastic).
# @SamsungSupport Is it normal for Samsung Supervisors to not answer emails after a week?  Is it normal for Customer Service Reps to constantly put you back in the que?  Please let me know if this is a standard Samsung Practice.  I'm pretty irate right now.
# Product warning - Stay away from @SamsungSupport products @HomeDepot unless you like getting the run-around.
# @SamsungSupport Hi! I have a Samsung refrigerator that needs to have the ice maker replaced. As I look online for it it says its been discontinued. The model is da9705037a. Is there a substitute for this ice maker model that will fit? Thanks
# @SamsungSupport Does S21 Ultra(SM-G998U1) support 5G band n77?
# @SamsungSupport We own a 55” Samsung that has NEVER worked properly (does not shut off). Have had three technicians who have not solved problem. We want the TV REPLACED. IT IS A LEMON! Samsung has not performed up to the high standards we expected when we purchased the TV
# @AIAPhilamLife  the latest version of your #philamvitality sucks! it's not syncing with my @SamsungSupport health no how you delink-link-delink it. you need to fix this now!
# @SamsungSupport It's a fitness watch 🤦🏾‍♀️ Why would that feautre be taken away! Makes no sense at all
# Why did y'all remove the "Calories Feature" on the Galaxy Active 2. As a fitness junky I'm not happy about this @SamsungUS @SamsungUS @Samsung @SamsungSupport
# @AIAPhilamLife the latest version of your #philamvitality sucks! it's not syncing with my @SamsungSupport health no how you delink-link-delink it. you need to fix this now!
# @SamsungSupport I just recently got you odyssey G5 27" curved monitor and within 5 days already a dead pixel.... 5 days.
# @SamsungSupport Thank you but I want to turn them on! Currently when I miss a call I have no way of knowing - the missed call notifications are not being displayed.
# @SamsungSupport Phone only. Thank u
# @SamsungSupport the galaxy buds live need the ability to change what all the taps do. I.E. I don’t want one tap to do anything because it pauses/plays your audio when you’re adjusting the buds in your ears. I think double tap should be play/pause. Also I’m using an iPhone X
# @SamsungSupport why are phone notification options greyed out? #Samsung https://t.co/exSHg805XA
# RT @victorious11182: @SamsungIndia @SamsungMobile @SamsungSupport @jagograhakjago
# @ConsumersAffair
# @nch14404
# worst quality of handsfree . W…
# @SamsungIndia @Samsung @SamsungSupport @SamsungUS This is continued 4th day i am tweeting and no one replies. So much for the brand value
# Hay @SamsungIndia @SamsungSupport
# Fix this
# My phone Samsung galaxy a30 has many problems on One UI 2.0 so fix this please https://t.co/KCbO1w2CeQ
# 😊🙏
#
# I didn't feel alone because of y'all 🙂
#
# Thanks 🙏🙂
#
# @SamsungSupport  🌟
# @Samsung  🌟
# @SamsungMobile  🌟
# @SamsungSupport @SamsungMobile @SamsungMobileUS I have a dead pixel on my Note 20 ultra 5G, how can I get it fixed? Is it within warranty? i have a case on it, never dropped.
# @SamsungIndia #fakepromise Issues with the same AC within 1month of purchase @SamsungIndia @SamsungSupport @Samsung @SamsungService
# @SamsungSupport bruh why android 11 is not commin to note 9 series? we all know the hardware is capable and it's been 2 years since the release of the phone. it's not even old yet. not epic. please release the new version so al least the phone is supported for 3 years.
# @SamsungSupport Galaxy M30 will get one ui 3.0 update? I mean it received android 9 and 10 major updates previously. So any chance of getting android 11 update(ui 3.0) in it?
# The Agent just referred me to a in town repair shop ( NOT AND OTHORIZIDE  SAMSUNG DEALER )and i have the pay the bil🤣🤣🤣🤣 THIS TOO BAD @SamsungMobile @Samsung @SamsungSupport #samsung
# Wtf @SamsungSupport I don't want to upload my contacts for Samsung Notes in order to view my damn already shared notebook!! Remove that crap!
# @SamsungSupport Can you see DM please?
# @SamsungSupport I didn't receive my smart tag with my s21 ultra pre order. Phone is here but not the smart tag
# RT @WynonnaOz: @SamsungSupport @Android #androidhelp
#
# Please see above. I need help with my s10+
#
# Is there a way to customise the way apps…
# @SamsungSupport Thank you for the quick reply. I will reach out tomorrow morning.
# @SamsungSupport Your support chat is well aware of who I am.  I’m regularly ignored.
# @SamsungSupport Do I need to send the well worn band or charger with my Galaxy Watch trade in, or just the watch body itself?
# RT @Rekha4288: @SamsungMobile @SamsungIndia @SamsungMobileUS @SamsungSupport
# We are using Samsung since last 10yrs in my family, colleague…
# @SamsungSupport Does it matter at this point. The live customer service dept is an absolute failure. And the Twitter customer service has been nothing but lip service. But I can try.
# @SamsungSupport Why did you make fun of Apple for removing the adapter, then you did it yourself?
#
# Copying Apple makes me want to stay with Apple, because there is no one different to go to.
# @jeremynewberger @SamsungUS I’ve literally been asking @SamsungUS @SamsungSupport to address this issue for at least a year. I started having issue 6 months in in 2018. And they are STILL making them. Models since 2009 have issues.  Good news is you can get a refund if you jump through some hoops.
# @HomeDepot and @SamsungSupport @SamsungUS 2 billion $ companies and neither one will take responsibility for my damaged oven. Pay $1500 for an oven that was dropped and neither will exchange or replace my useless oven. Can’t afford to pay another $1500. Customer service is dead.
# @SamsungSupport @SamsungUS @HomeDepot Bought a samsung oven from home depot. Three days later we have it installed only to find out it had been dropped and there was undetectable damage underneath. Both companies refuse to have the item returned. $1,500 down the drain
# @SamsungSupport has the absolute worst customer service I have ever experienced in my life. After all the money I've spent on their products, the runaround that they're giving me is unacceptable. @SamsungMobileUS @samsung @SamsungMobile #SAMSUNG
# @SamsungSupport Installed the software update for my #Active watch today. It reset some of my preferences/screens - I'm not thrilled (and accordingly, I will be wary of future updates!).
# @SamsungSupport Hey, how do I get blood oxygen readings on my Active 2 watch? Is there an app that I need to add? TIA for any help.
# RT @SamsungSupport: We took the Galaxy S series to the next level with the #GalaxyS21Ultra. Wondering how? Click below for an infographic w…
# @SamsungSupport so are we going to play this game again? Had to call to speak to a live person on Thursday. Said they would get back in 1-2 biz days with a resolution. 1-2 biz days would put me until today. What’s wrong with this picture - besides the one on my TV not working?
# @SamsungSupport Bad bot
# When yal gone give us the solar powered phone?
#
# @SamsungMobile @SamsungUS @SamsungSupport @Samsung
# @SamsungSupport Good hands with a 2 hour wait 😂 ridiculous.
# hey @SamsungSupport when will y'all be releasing a 4k 120 HZ monitor so I can game better on my @PlayStation 5? Trying to keep my electronics in the @SamsungUS Family
# @SamsungSupport oh.... It was an iphone SE 😑. An hour to speak with someone. 😂 Ridiculous. https://t.co/EUVlK61QhU
# @SamsungSupport I was just told by a case mgmt agent that Lowe's will now be processing a store credit for my wife and I to order a new fridge.  Is this the standard operating procedure for a busted fridge that can't be fixed?  Someone should reach out to me ASAP.
# Current call is now near the 20 min mark. No one can tell me what happened to the phone and no resolution has been offered. Blame keeps getting shifted to repair team who isn’t responding at all. @SamsungMobileUS @SamsungMobile @SamsungUS @SamsungSupport you suck, respectfully.
# @SamsungSupport some of the worst customer service I have ever received in my life. Do NOT buy Samsung. Sent in my phone on 2/3/21 ... was received 2/8/21 ... still don’t have the phone, now they claim it’s a tablet I sent in and have no record of the IMEI I provided. https://t.co/I67djMqOi4
# @SamsungSupport  Samsung Customer Care, is thee worst!!!
# @SamsungSupport please help. My dryer is giving me and error. This thing is nowhere near its life expectancy.
# Funny how after 2 days of calling @SamsungSupport about a repair request that they suddenly cancelled despite it being within the warranty period, there's all of a sudden impact damage that wasn't included in the ticket until literally just now.
# @SamsungSupport I just got a new S21 Ultra and followed your steps for free YouTube Premium and it charged me. How can I fix this?
# @SamsungSupport I'm good, thanks!
# @SamsungSupport Ok DM message You
# @Samsung @SamsungSupport @SamsungUS why does it says that the battery will last 13 hrs but when I fully charge mine, it states less than 3 hours? I always put all my devices to use as little battery power as possible. https://t.co/HZDIRXwXyW
# @SamsungSupport Hi, I recently got a Samsung device after a pretty long time and can’t login with my Samsung Account to the new phone because i had 2fa on with my old phone number, any possible solution to get my account back please? 🥺
# @SamsungIndia @SamsungMobile @SamsungSupport @jagograhakjago
# @ConsumersAffair
# @nch14404
# worst quality of handsfree . Within 6 months three replacement . No response from Samsung even though I have made series complaints on Samsung whatsapp number
# @SamsungSupport I bought new S21 with premium care plan. I will still billed for my previous plan even though I no longer have phone. Can that be refunded?
# @Samsung @SamsungTV @SamsungSupport Need help finding the right Tv!
# RT @manmohanb46: @Kiran21706515 @Kish_RKSingh @RohitNi26493718 @mksweetguy @SohanKu02275834 @brazz_k @Suraj_s_shah @Abhishe74607858 @Kedarn…
# @SamsungSupport I've yet to hear back from any live support agent regarding my order. Samsung continuously delays the delivery date and they blame it on the weather (it's not though). Then, they'll say it will ship out in two days only for them to add an extra 2 weeks onto the delivery date.
# @SamsungSupport I promise you that I'd this company bothered to release a screen protector that doesn't suck, people that own Samsung's would buy them because there isn't any other way to protect our phone screens.
# @SamsungSupport I've wasted so much $ on these crappy screen protectors because they don't go on smoothly, god forbid you accidentally touch a corner of the sticky side &amp; there is a permanent smudge, even if wearing gloves. Then I have to go out and buy ANOTHER protector &amp; re try
# @SamsungSupport Guess what? I called the number and the automated system said due to limited phone support, text some other number, then it hung up on me. This is the customer service Samsung provides. Your trade-in program is a scam. People should be warned!
# @SamsungSupport is literally the worst. I have never dealt with a more incompetent customer support system ever. It’s honestly astounding that almost 3 months into this process and I still have not been able to get my tv fixed or replaced. Worst warranty process ever
# @SamsungSupport Is there any other contact way? Like live chat or something
# @SamsungSupport I order a tab s7 from few hours but I received that my order cancelled because they couldn't confirm my payment info. (The price of the tab was taken from my bank account)
# @SamsungSupport Absolute worst customer service experience EVER. I get a monthly charge of $5.33 from Samsung. I have tried for over an hour to find out what the charge is for. Shameful
# RT @manmohanb46: @Kiran21706515 @Kish_RKSingh @RohitNi26493718 @mksweetguy @SohanKu02275834 @brazz_k @Suraj_s_shah @Abhishe74607858 @Kedarn…
# @SamsungSupport A51 new out of the box, wifi calling not functioning. 4 days of tech support with Verizon and they say the phone is defective. Taking it back and getting an LG... #GarbagePhone
# @DorothyFrisch1 @FridgeRecall @jeremynewberger Same here. DM to @SamsungSupport was responded to quickly, process went smoothly.
# @SamsungIndia @SamsungMobile @SamsungMobileUS @SamsungSupport
# If any incident will be happened with me who will be responsible on it.
# @SamsungMobile @SamsungIndia @SamsungMobileUS @SamsungSupport
# We are using Samsung since last 10yrs in my family, colleague, frd, relative also. But I was using Samsung Duos Model SM-G7102, during watching video on Youtube it was start over heat and caught fire ( burn),
# @SamsungSupport I did, and it was as useless as your phone support. "DM me with your inquiry" so consumers can't see the constant dissatisfaction being posted on your feed.
# @jeremynewberger @SamsungSupport what say you?
# @SamsungSupport I just get really upset by being enticed by a promo to only be told "sorry that promo is no longer valid"!
# So post, free free free, so I buy something and get aggravated later by another false claim! I'm sure I'm not the only one to fall for this. Remove the free promo claim.
# @SamsungSupport If that promo for the free charging pad is old and no longer valid (apparently for months now) why is it still being advertised?
# @SamsungSupport I did last week. 2 hours on hold and my issue was not resolved!
# @SamsungSupport can you please let me know the india,s twitter handle where i can write my complaint of refrigerator.  Thanks
# @SamsungSupport Hello, I have a question regarding a order and the payment that was used for that order.
# RT @CityGir12046362: @SamsungSupport Thank you for your response which was the same. If you have to return it again for the 3rd time we wil…
# @SamsungSupport Coincidence or conspiracy that it all of a sudden works again.....
# @SamsungSupport hey your last update ruined the Always On Display ability
# RT @malani_j: @SamsungMobile @SamsungIndia @SamsungUS @SamsungUK @SamsungMobileUS @samsungID @Samsung @SamsungMobileSA @SamsungTV @SamsungS…
# @SamsungSupport I mean, I don’t have a lot of choice at this point 😉 how do I do that?
# @SamsungSupport Thanks - tried that multiple times already ove the course of the morning, but it keeps getting stuck on the Samsung logo.
# @SamsungSupport @BrianncaTV Hello, you might want to try https://t.co/ENwOJsgL68 a powerful and robust social media management tool to handle all your social media accounts across major platforms. Try it and you will surely like it. They offer a free trial on the link below.
# https://t.co/rjtYUukxld
# @JKashaar @SamsungSupport can you get into the bootloader
#
# if so you could factory reset your phone
# https://t.co/2MSEgoQIev
# Woke up today to my phone having bricked itself over night. This S7 worked perfectly fine last night, this morning it’s stuck in the boot screen. What should I do, @SamsungSupport?
# I have done it but but the update does not happen, the bankers deduct fees to be dmi finance bounce. @DMIFinanceUK
# @SamsungIndia
# @SamsungMobile
# @SamsungSupport #dmifanance
# @SamsungMobileUS received my S21 5G ultra whatever that is, 3times heavier than my #GalaxyNote10+ I don't know if that's bold move as an upgrade or send this back? @SamsungMobile @SamsungUS @SamsungSupport
# @SamsungSupport Hi, I have the Samsung odyssey G7 and have the firmware ver 1009.3, it still doesn't fix the flickering problem. When does the next fix come out ?
#
# thanks guys
# @SamsungSupport Bot refrigerator side by side model. after 8 months only gas leaked . what a product for 93 K. out of 4 refrigerators that I purchased  in my life its first time  such a poor quality refrigerator. NEED EXCHANGE IMMD.
# @geegeorg @SamsungSupport so,  pls let me know are you satisfied with Bestisan soundbar? It means a lot to me.

# %%
df = pd.read_csv('tweet_reply_Samsung.csv')  
df.to_csv('analyze_tweet_reply_Samsung.csv', header = ['Comments'])

# %%
df1 = pd.read_csv('analyze_tweet_reply_Samsung.csv')
df1.shape
# Out:
# (722, 2)

# %%
import re
import string

def clean_text(text):
  text = re.sub('@[\w]*','',text)
  text = re.sub('\[.*?\]','',text)
  text = re.sub('[%s]'% re.escape(string.punctuation), '',text)
  text = re.sub('\w*\d\w*','',text)
  text= re.sub(r'@[A-Za-z0-9]+','',text) #remove mention
  text = re.sub('https?://[A-Za-z0-9./]+','',text) #remove https
  text = re.sub('b\w*','',text)
  return text

cleaned = lambda x: clean_text(x)

# %%
df1['Comments']= pd.DataFrame(df1.Comments.apply(cleaned))

# %%
df1
# Out:
#      Unnamed: 0                                           Comments
# 0             0     visited service centre in Palwal Haryana In...
# 1             1    On ALL my Samsung phones the same  in the Yo...
# 2             2   The Galaxy  was delivered with no watch  Supp...
# 3             3    This will  the first of possi endless days i...
# 4             4                        why was my order cancelled
# ..          ...                                                ...
# 717         717   have done it   the update does not happen the...
# 718         718   received my   ultra whatever that is  heavier...
# 719         719   Hi I have the Samsung odyssey  and have the f...
# 720         720   Bot refrigerator side  side model after  mont...
# 721         721    so  pls let me know are you satisfied with B...
#
# [722 rows x 2 columns]

# %%
df1 = df1.drop(["Unnamed: 0"], axis=1)
df1
# Out:
#                                               Comments
# 0       visited service centre in Palwal Haryana In...
# 1      On ALL my Samsung phones the same  in the Yo...
# 2     The Galaxy  was delivered with no watch  Supp...
# 3      This will  the first of possi endless days i...
# 4                          why was my order cancelled
# ..                                                 ...
# 717   have done it   the update does not happen the...
# 718   received my   ultra whatever that is  heavier...
# 719   Hi I have the Samsung odyssey  and have the f...
# 720   Bot refrigerator side  side model after  mont...
# 721    so  pls let me know are you satisfied with B...
#
# [722 rows x 1 columns]

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading https://files.pythonhosted.org/packages/60/f0/1d9bfcc8ee6b83472ec571406bd0dd51c0e6330ff1a51b2d29861d389e85/textblob-0.15.3-py2.py3-none-any.whl (636kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\hp\anaconda3\lib\site-packages (from textblob) (3.4.5)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.15.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3

# %%
from textblob import TextBlob
import nltk
# nltk.download('punkt')
# nltk.download('brown')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('wordnet')

# %%
def get_polarity(text):
  return TextBlob(text).sentiment.polarity

df1['TBpolarity'] = df1['Comments'].apply(get_polarity)

# %%
df1
# Out:
#                                               Comments  TBpolarity
# 0       visited service centre in Palwal Haryana In...     0.20000
# 1      On ALL my Samsung phones the same  in the Yo...    -0.03125
# 2     The Galaxy  was delivered with no watch  Supp...    -0.60000
# 3      This will  the first of possi endless days i...     0.06250
# 4                          why was my order cancelled      0.00000
# ..                                                 ...         ...
# 717   have done it   the update does not happen the...     0.00000
# 718   received my   ultra whatever that is  heavier...     0.00000
# 719   Hi I have the Samsung odyssey  and have the f...     0.00000
# 720   Bot refrigerator side  side model after  mont...    -0.03750
# 721    so  pls let me know are you satisfied with B...     0.45000
#
# [722 rows x 2 columns]

# %%
df1['Sentiment_type']= ''
df1.loc[df1.TBpolarity>0, 'Sentiment_type']='POSITIVE'
df1.loc[df1.TBpolarity==0, 'Sentiment_type']='NEUTRAL '
df1.loc[df1.TBpolarity<0, 'Sentiment_type']='NEGATIVE'
df1.head()
# Out:
#                                             Comments  TBpolarity  \
# 0     visited service centre in Palwal Haryana In...     0.20000
# 1    On ALL my Samsung phones the same  in the Yo...    -0.03125
# 2   The Galaxy  was delivered with no watch  Supp...    -0.60000
# 3    This will  the first of possi endless days i...     0.06250
# 4                        why was my order cancelled      0.00000
#
#   Sentiment_type
# 0       POSITIVE
# 1       NEGATIVE
# 2       NEGATIVE
# 3       POSITIVE
# 4       NEUTRAL

# %%
df1 = df1.drop_duplicates()

# %%
df1.shape
# Out:
# (669, 3)

# %%
df1['Sentiment_type'].value_counts()
# Out:
# NEUTRAL     252
# POSITIVE    236
# NEGATIVE    181
# Name: Sentiment_type, dtype: int64

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
sns.countplot(x ='Sentiment_type',data = df1).set_title('SamsungSupport')
plt.show()

# %%
# Wordcloud libraries and Tweepy API
import sys
import string
import json
from collections import Counter
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import tweepy
from tweepy import OAuthHandler
from tweepy import Cursor

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
def word_cloud(wd_list):
    stopwords = set(STOPWORDS)
    all_words = ' '.join([text for text in wd_list])
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        width=1600,
        height=800,
        random_state=1,
        colormap='jet',
        max_words=80,
        max_font_size=200).generate(all_words)
    plt.figure(figsize=(12, 10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation="bilinear");
word_cloud(df1['Comments'])
