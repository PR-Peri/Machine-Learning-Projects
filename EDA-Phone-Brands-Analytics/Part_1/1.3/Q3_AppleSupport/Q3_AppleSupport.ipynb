# %%
### Imports go here
import tweepy
# !pip3 install twint
#import twint
import json 
import datetime
#import geocoder
from tweepy import OAuthHandler
import csv

# %%
# load/read from file using JSON
secrets = json.loads(open("secrets_Apple.json","r").read())

api_key = secrets['CONSUMER_KEY']
api_key_secret = secrets['CONSUMER_SECRET']
access_key = secrets['ACCESS_TOKEN_KEY']
access_key_secret = secrets['ACCESS_TOKEN_SECRET']


auth = OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_key, access_key_secret)
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

#change per brand
screen_name = "AppleSupport"

# %%
import pandas as pd

# %%
import csv
csvFile = open('tweet_reply_Apple.csv', 'w')
counter=0

csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q='@AppleSupport',count=4000000,lang="en", tweet_mode='extended').items(4000):
    print (tweet.full_text)
    csvWriter.writerow([tweet.full_text.encode('utf-8')])
counter+=1

csvFile.close()
# Out:
# @AppleSupport where is the Black Family emoji with the father in the home⁉️U have had several updates with a new phone dropping. Where is the Black Family Emoj?! 🤔
# my iP11 aftr taking any photo then going to my album to review the photo,they are blurry.Every one of them.But,if I pinch in then back out to the original size,the phot suddenly is no longer blurry,it looks fine. so annoying and why?? @Apple @AppleSupport
# @applesupport my dick i stuck in my macbooks usb drive help me u fokingggg baka
# @AppleSupport
# Hi since 2 hr , and I receive wrong activation code to verify my new account ? And its not work https://t.co/Gh3qXflMsA
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# @TheGirlJE @AppleSupport You know I’m still new to this phone so idk 🥴
# @TheGirlJE @AppleSupport If you switch back right after I finally switched... we gon have a problem MAAM https://t.co/MyP9G9HKOS
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# @AppleSupport No metronome watch apps are working on the Watch... NONE.
# @AppleSupport good morning, can you help please? I’m trying to install Flume on my Mac but it says that I do not have permission to do so. I’m the only user and admin of this Mac. I don’t get it?!? https://t.co/fvKVD2wE3u
# @AppleSupport I turned on Notes with iCloud after recently putting my phone in recovery mode. Everything from my MacBook’s on my iPhone, but everything that was just on my iPhone is gone. As you can see, there’s nothing in the other folders, so idk where the rest of my notes are..... https://t.co/nnUGmRqguB
# @AppleSupport So if my battery swells and needs to be replaced when the diagnostics and software say it's operating at peak performance, should I have to pay for the replacement? #Apple #appleinternal
# @AppleSupport You needed to point @U2 sorry a$$ songs off MY. Not your phone
#
# Is Bono gona chip in on this over priced tracking device?
# No? I’m subject to his ego for free?
#
# Get this garbage off my property please Siri.
#
# Ya ingenuous c***!
#
# I’m unsure why you believe you were entitled to do?
# @Apple  @AppleSupport no any response coming from apple service.
# @yagirlkinah It’s literally always something with these people lately 🗿 When my tweets start coming from Twitter for Android... yeah @AppleSupport you should be VERY scared!
# @O2 @AppleSupport I bought a magnasafe charger for my new iPhone however it flicks in and out of charging and loses charge quicker than it charges so serves no purpose. I bought through o2.... please can you tell me how I can get this replaced? Thanks in advance!
# @AppleSupport
# Please what is happening to Apple Music ???
# Happy to post a positive update on this, was surprised to see the issue get resolved swiftly &amp; silently! Relieved that #MyAppleLife feels normal again! Many thanks @AppleSupport https://t.co/lQQ59Xigo0
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# @AppleSupport Hey! I can’t download my https://t.co/PHnKL2ZzDE data export. Can you assist? https://t.co/8q13ezB2ZM
# @KeiaBlackfeathr @AppleSupport @Apple Kinda I had to work with the calling
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# @AppleSupport will you add a system preference for the #Deaf people to mute any sound forever? It's so embarrassing for my colleagues to hear whatever I'm doing while I don't! #justice #fairness #accessibility
# RT @Dr_angiee: @AppleSupport @Apple Dear Apple, I did not authorize this transaction, I would like a refund immediately.
# Please see that m…
# Please you guys should help me rt and @AppleSupport @Apple
# I can run mad, they no Dey see the kin money with two eye waka straight 😭😭😭😭😭
# @googledrive @AppleSupport why are you only allows WhatsApp to take back up on Google Drive, we need more option like on iCloud
# @Apple @AppleSupport I can’t find the built in internal speakers option for the output. I removed the headphones already and disconnected everything, but it didn’t show up still. Help me please 🥺👉👈 or else my grandfather kills me 😿😹 https://t.co/sieFeH4p2Z
# @AppleSupport why are you only allows WhatsApp to take back up on iCloud
# Please you guys should help me rt and @AppleSupport @Apple
# I can run mad, they no Dey see the kin money with two eye waka straight 😭😭😭😭😭 https://t.co/5vyyIMiLqj
# @nashasgoodtakes ok maybe this has to do with my phone @Apple @AppleSupport @apple this shit aint working!!!
# @AppleSupport hi, my phone has been working fine until this week. Now when I make a call the receiver can’t hear me even on loudspeaker. I’ve tried recording videos and the sound works fine on them. Do you have any idea?
# @AppleSupport @Apple Dear Apple, I did not authorize this transaction, I would like a refund immediately.
# Please see that my request is tended with immediate effect, thank you. https://t.co/s3VaQDsH0X
# @Peter9_0 @disneyplus @AppleSupport Honestly it’s probably @disneyplus’s problem. Their web player is complete garbage that doesn’t even let you select your playback resolution or bit rate. I experienced similar crashes on both Firefox and Chrome on my PC. I had to use MS Edge to get stable playback.
# @AppleSupport  since the iOS 14.4.1 update my iPhone 7 battery is draining rapidly. From fully charged to battery at 1% in 2 hrs
# Is there a fix for this? Help!
# @AppleSupport Worse customer care in Middle East ... I had to struggle between the authorized Maintence center and your advisors who claim that they can’t help me unless they call me over the phone and get me charged for that !! Awful 😪
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# @AppleSupport Search emoji is a life saver!
# @AppleSupport @ark_keeper Is @AnkerOfficial still certified? They don’t show up on the official list: https://t.co/XjYuhjYJ9O
# @AppleSupport kindly check your DM. @Apple kindly tell your support to neck their DM
# @jack @Apple @AppleSupport I only have to set the right time &amp; date, but this is how I woke up😍 https://t.co/o5eNDReOyM
# @bangtanieex @Apple @AppleSupport Struggle iz real HAHAHA :((
# @AppleSupport one of the worst support for repairing my Mac in Pune. No ETA, very frustrating and unprofessional support for service center and apple support.
# @suger_1992 @AppleSupport Try out hubunlock on Instagram to get it unlocked without loosing data , they helped me out with mine
# @Apple @AppleSupport help please
# @AppleSupport @Apple
# is it really possible ??
# #Iphone11 #Apple https://t.co/1Oo4ohK6jp
# @Apple #Iphone11
# Is it really possible ???
# Do my sister and me really look so similar that even technology gt confused .
# @AppleSupport https://t.co/aaFouo3FPk
# Why @telegram on CarPlay doesn’t have a chat list as iMessage? Is it an @Apple limitation? @AppleSupport
# @applesupport where the ibook g4 released yet
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @AppleSupport i am having a lot of issues with my AirPods Pro, the right one isn’t charging anymore. The device has been reset, I’ve cleaned the surfaces and still isn’t charging 😪
# @AppleSupport had to put it on the back burner. But after 20minute phone call today has been solved! Great service. The apple Configurator 2 was a old version that didn't support 2fa. But now my question is why @JamfSoftware pushed 2.9 when the latest was 2.13 to a brand new intel Mac mini?
# Is it just me or.... whenever we use our Safari on MacBook Air or Pro to watch @disneyplus the web browser was constant crash and reload our shows/ movies? @AppleSupport any ideas?
# @AppleSupport @apple @AppStore
# hello #apple from France 👋🏻🇫🇷🥖
# Is it planned, during a next update of Ios, that we can manuelly organize apps in app library as we wish, to do our own categories ; keeping the alphabetical classification of course📱
# Thank you 🙏🏻
# #ios #iphone
# @AppleSupport You want me to give you feedback on why there is no BAHASA INDONESIA under the keyboard input section? Can you not give a response as to how I am supposed to type in Indonesian? Even if I change the OS language to Indonesian the keyboard does not recognize it.
# @AppleSupport I didn’t receive it either. I even tried to input my workouts but it didn’t work.
# @AppleSupport why can’t I copy paste email addresses without that nonsense before the email address
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# @AppleSupport Your notes app is killing macos cpu in list view! I have same issue on m1 air 13” https://t.co/rwbSCYWp6G
# @AppleSupport just got my first iWatch. Not getting text tones on my phone is so infuriating I want to return it. #notHelpful #givemethechoice
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @Apple @AppleSupport @WhatsApp check the attached screenshots 1st is from settings where it shows there's 2.09GB of Docs and data 2nd is from WhatsApp itself where it shows that only 530.3 MB is used.
# Why this much big discrepancy is there. Pls make me understand or if https://t.co/LmvVWQuokA
# Hi @AppleSupport  - I’m talking to “Vicky” from chat services who says that she can’t allow me to talk to a supervisor for a scam order and fake publicity and I have to wait five business days to talk with a supervisor based on our interaction right away ? @tim_cook WTF!!! https://t.co/8f8tFa6vyw
# I mean @AppleSupport
# @applesupport are yall makin new games on the pippin
# THREE WEEKS and not even ONE DM from @Apple or @AppleSupport re #iMac random TWO YEAR shutoffs🤔 #WhatASurprise
# #ReadMyThread 👆🏼👆🏼👆🏼&amp; #ReadThis https://t.co/ObxZ5yTxLw
#  #ClassAction #AppleExperience #CustomerExperience #consumerservices #Crickets RT
# @AppleSupport  it’s been 3 days of trying to update to Mac Bigsur and I keep getting an error message it won’t let me reset or anything it’s been 3 days since since I’ve last been able to use my MacBook
# @AppleSupport In @WhatsApp as well as in camera app https://t.co/SAKRWkmzK8
# What do I do if one of my AirPods doesn’t work anymore @AppleSupport
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger Stalker 11:03 and after what just happened that I reported to AG I'm not taking these Stalkers lightly https://t.co/LDFXmDcP6A
# @Apple @AppleSupport why is my 2017 MacBook Pro not getting a free service,it has the same backlight /flexgate issue like 2016 batch &amp; it is a quality issue on your side !! @AppleIndiaForum #applesupport #applesupportindia #MacBook
# @AppleSupport Dear until now nobody is responding @Apple
# @AppleSupport Thanks.
#
# Do you have any support in Japanese?
# There are many other things, so it's difficult to explain the details in English.
# @AppleSupport
# @Apple
# I have repaired by old iphone and I can't start it as I have forgot it's iCloud ID and Password. Help please!
# MY PHONE DOESN'T WORK NOTHING WORKS WHAT THE HELL help @Apple @AppleSupport
# RT @CapsicumFry: @iamnagarjuna @Apple @AppleSupport phone konte soap delivery ichada sir? https://t.co/TsT1gVZrEr
# @AppleSupport hello, i have smth problem with my payment methods. i add DANA acc and debit online mastercard for the payment on Indonesia App Store, but it reportedly failed. can you help? https://t.co/d76L8Zljj7
# RT @CapsicumFry: @iamnagarjuna @Apple @AppleSupport phone konte soap delivery ichada sir? https://t.co/TsT1gVZrEr
# RT @CapsicumFry: @iamnagarjuna @Apple @AppleSupport phone konte soap delivery ichada sir? https://t.co/TsT1gVZrEr
# @AppleSupport Hye! How to get my refund because canceled my order?
# @SaraEleta @AppleSupport I did the 3 month trial. Took my small Napster/Kazaa MP3s and gave me clean  higher res. AAC files. It’s nice to see my ripped CDs in the cloud.
# @Apple @AppleSupport y’all really got some shitty fuckin chargers... what is this like the best possible one you can get the box mf? Correct??! This bitch is really like 40$ and it stops working for me believe me I’ve tried everything to make it work and fix it but Na still broke https://t.co/6p0ci0s8Iz
# @AppleSupport Is there a way to get device management back with out installing beta software?
# What the fuck @AppleSupport https://t.co/QDC9XZs0YR
# RT @AppleSupport: @bfrancis84 Thanks for reaching out to us. We’re here to help. Let’s have you try resetting the SMC as shown here: https:…
# @AppleSupport has turned out to be the worst exp ever. They replaced my MacBook speakers twice in the last 4 months &amp; they again go bad (not to forget the 2 weeks TAT). Better buy 2-3 lenovo machines in the same price.
# #Apple #MacBookPro
# @classicURGE @AppleSupport Sounds good. I'm not an Apple Music user. Might give it a go one day, but been pretty happy with Spotify and SoundCloud
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @SaraEleta @AppleSupport Probably wouldn’t apply to a hip person like you but I also signed up for Apple Music. Used it to match my music to the cloud and download my collection at a higher bit rate from iTunes on my new Mac.
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger Stalker 10:17pm
#
# Keep pushing https://t.co/M3IvMXtvM8
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# RT @Charwaahaa: Dear @AppleSupport
# You should’ve easily named the new macOS “Big Shit” instead of “Big Sur”
# ہر اپڈیٹ پر کریش کرتا ہے 🤮🤮🤮
# @classicURGE @AppleSupport Probably a good idea. No indication that it's even working. Just says "getting started"... hours...
# Every fucking macOS update requires me to run
#
#   xcode-select --install
#
# WHY?!!!!!!
#
# (Well, security, probably, but.. WTF, @applesupport?)
# RT @foreversereda: Dude I just realized now the battery in my Mac is about to explode and has popped the aluminum casing from expanding. My…
# Why the fuck does it say I got IOS 14.4.1 update when I supposed to get 14.5?
#
# @AppleSupport
# @ritzyveins @Apple This is a really good idea. And it doesn’t seem like it should be too hard for them to do. @AppleSupport @AppleSupportUSA
# @AppleSupport : Bought a new iPhone XS from Walmart paid fully. Travelled abroad, it says sim not supported when tried local sim. Please suggest.
# @SaraEleta @AppleSupport I skipped migration. I copied my documents folder to a External HD and just installed apps I used. I had so much extra cruff I didn’t want transferred.
# @AppleSupport @Apple So no reply for the pain??
# RT @televangeles: 6 weeks of back and forth with
# @AppleSupport
#  with every single person agreeing this is crappy battery.
#
# But the final w…
# @foreversereda @AppleSupport Better get on that ASAP
# @Apple @AppleSupport how can I go online on your chat when it wont work should be able to chat using the chat button asking phone info which I cant get when it wont even turn on HELPPPPPPPPPPPPPPPPPPPPPPPP
# @Apple how to contact you? what is your email? my phone wont turn on how can I do the online chat when its asking my serial number which I cant get since my phone wont even turn on? hellppp @AppleSupport
# RT @foreversereda: Dude I just realized now the battery in my Mac is about to explode and has popped the aluminum casing from expanding. My…
# @AppleSupport Why does deleting albums I added to my library remove the songs they have from playlists I made??? https://t.co/IWSbATYWCT
# Dude I just realized now the battery in my Mac is about to explode and has popped the aluminum casing from expanding. My Mac could explode any minute and I haven’t backed up my music in 6 months MonkaS!!!!!! @AppleSupport
# @AppleSupport I’ve just raised a ticket after chatting with support. Thank you.
# @RachelTrue @Apple @AppleSupport Curious if Apple has confirmed this is because true is a boolean. Might not be related to that coincidence
# Dear @AppleSupport
# You should’ve easily named the new macOS “Big Shit” instead of “Big Sur”
# ہر اپڈیٹ پر کریش کرتا ہے 🤮🤮🤮
# @AppleSupport I tried the steps and I still have issues. The left airpod just won’t work
# So a MacBook migration transfer takes several hours over wifi, huh?
#
# @AppleSupport
# @AppleSupport Got it.
# But, I don’t use emojis. ;( https://t.co/YXFyhygg4h
# @AppleSupport It worked itself out. Thank you!
# @jsrailton @TMobile @DrewFitzGerald @AppleSupport T-Mobile should not be allowed to have iPhones any more. They are not aligned with your privacy first Vision
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @AppleSupport No and yes
# Another week goes by without my iMac @Apple @mobilekangaroo @AppleSupport
# @AppleSupport Hello, is this a bug on your end, major UX fail or am I doing something stupid?
# https://t.co/m4yEluFtUf
# Thanks
# Do y’all gave a Face ID keychain feature ? I’m curious @Apple @AppleSupport https://t.co/xXbbUqbnJd
# @AppleSupport  how can I burn 0 calories on a 5k run? https://t.co/3BZp6cMiKz
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @AppleSupport Hello apple I have a problem with typing and I dmed you
# I need a way to mark my iMessages as “unread” so I don’t forget to respond.
# @AppleSupport @Apple Help!
# @TwitterSupport the likes keep disappearing on this tweet. Please fix your glitchy system !! @AppleSupport https://t.co/w5ilaiHfef
# @BenAdamsonDXB @appleinsider @AppleSupport I dont need an i-vibrator...I need a professional grade MacBook pro
# @Apple @AppleSupport not to mention this is the third time these new chargers breaking in this fashion has left me without a charged phone when i need it.
# RT @JustinNoelDev: Anyone know how to disable the "focused" controls in macOS? This just started when I updated to Big Sur. This is showing…
# @AppleSupport I didn't get the womens day award? i tried restarting my watch yesterday but it never showed up
# Also while I'm on this fire rage @Apple we spend $1200 on your phones and then you're like "oh you have 200 photos and 3 apps? Your space is full bye" fuck off @AppleSupport
# @AppleSupport support damn
# @AppleSupport I dont like you
# @AppleSupport How about some YouTubeTV support for Safari so I can uninstall Chrome?
# @Comedydaddy @AppleSupport I was thinking that too but it’s a weird foggy situation. Lol ... 5 hours now. Maybe needs longer. I’m just too excited lol
# @AppleSupport 5 hours
# @AppleSupport Thank you. DM'd. Can you please get @timcook on the line?
# @AppleSupport I went through the list of your games but none of them have a word game for the watch I wonder why
# @AppleSupport Hi, a friend of mine who has sent money to me before through Apple Pay, has once again sent a payment. Though this time, it's been stuck on pending for longer than usual, could you offer any advice on what to do?
# Has anyone experience their iPhone video being turned into a picture while you're editing it and then the edit button is gone? @Apple @AppleSupport
# @AppleSupport Hi, I have a problem with installing iTunes on my MacBook Air. At first it said that my Os version was too old for it, so I upgraded it and tried again. Now it says it needs an earlier version, what should i do?
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# ⁦@AppleSupport⁩ When I try to Airplay a video in full screen mode or tapping the Airplay button in the embedded video using Airplay on my LG TV, it comes up with blank screen, but if I exit full screen, it Airplays the video and anything else on my iPhone completely fine. https://t.co/RTtYaqfofo
# Thank you, @AppleSupport, FOR ABSOLUTELY NOTHING. My friends phone was STOLEN, and there was “nothing y’all could do” to help her change her Apple ID when we called to do a find my phone.
# @AppleSupport My "e" key came off my laptop. I have AppleCare :)
# @AppleSupport when removing a card from wallet since it’s expired. It won’t let me add my new one. Keeps saying already in wallet but it’s not
# @AppleSupport Shut your fucking mouth
# @amazon @AppleSupport @RogersMediaPR @Uber  money hungry company who don’t really care about their customer with poor service and reliability. Ignorant badtards
# @xenpi @AppleSupport I fin”y enen jnow wjat yoyet takin abuot
# @AppleSupport Look at this. I MADE SOME OF THESE SONGS WHY CAN’T I LISTEN TO THEM?? I don’t care if I live in Roflca. Mars needs more recognizion goshdamn it- https://t.co/ZubIRYvSTp
# @NorthernDennis @AppleSupport The ‘magic’ for me was lost during the process of purchasing and then using my 2018 macbook pro.  @Apple has lost their touch.
# @Lascurettes @Apple @AppleSupport It’s already downloaded. It’s the actual installation that is puking. Left it overnight and it finished.
# yo @AppleSupport how is it that i just bought my ipad last year, the new 8th gen 2020 one, but if i trade it in, its worth nothing?
# Hey @Apple @AppleSupport, with these past two updates, which take forever to download and install, my Bluetooth gives me disconnection errors for my AirPods and AirPods Pro.
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @AppleSupport I have iPhone and it is locked 🙁 it says “ iPhone is declined, concat to iTunes “
# I’m afraid if I contacted it to lose every thing and there is photo of my dead mom 💔 i will lose theme forever 😔 can you help me ? Please
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger And when I call this number all I get is static https://t.co/8eOnXV6JSV
# @grindr has the worst publicity out of  it’s competitors and yet NOTHING is done to shut this app down or block it from download!!!! @theSNP @scotgov @AppleSupport @policescotland https://t.co/mmP9BuzHKd
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger This has been sending for 30 minute https://t.co/XrD4NqLiOj
# @AppleSupport doesn’t send everything you need when you order replacement parts. Ordered a replacement beats pro earphone, Fitbit in the mail with out the rubber ear pieces. If I’m ordering for a lost earphone don’t you think I would need that? Be very careful.
# And you wonder why some of us want this app shut down!!!! 😡😡😡🤬🤬🤬🤬@grindr @AppleSupport @hackerone There’s fuck all security on this app!!! @PinkNews @fbi @JoeBiden @VP https://t.co/eeJIXReWx5
# @AppleSupport @bilger_michael Ad in german but support in english only. How funny :)
# @AubreeBowenSays @Apple @AppleSupport I knowwww. I was SO ANNOYED.
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @marcoarment @AppleSupport So i can’t even dismiss in bulk as notification center is pop’d under and hidden. I have to clear one by one. The angles weep for us: https://t.co/qWPfKON01A
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger On my phone you could see the video on the background but nothing showed up on the screenshot https://t.co/rpLXOpwuuq
# @AppleSupport Dear Team, my iPhone showing all the time memory is full and I m unable to open any of the apps even though I cleared everything ! Please help me out and my model is iPhone 6s.
# @AppleSupport I am absolutely shocked at horribly my experience with Apple has gone so far.  I literally have no options. @EA and @Apple have basically taken my money, given me nothing, and said it can’t be fixed. #Apple
# @marcoarment And @AppleSupport wonders why we hate Big Sur notification UI changes: https://t.co/LS5xMoZN15
# How silly of me to think that my new $1100 phone would come with AirPods and not the same headphones I’ve had for like 7 years. Thanks @Apple 🙄 @AppleSupport
# Oh, fucking wonderful. Just got disconnected. @AppleSupport, you truly do suck. https://t.co/MlKOqnGMDF
# @AppleSupport @tim_cook @EpicGames @FortniteGame GIVE YOUR CUSTOMERS FORTNITE BACK.
# Day #7 of tweeting @AppleSupport still no reply and no answer to my question.
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @AppleSupport whenever i try getting a free game it says i must use a credit card or payment method
# @AppleSupport Paid 4 Jan 2021  € +1,600 for an iPhone 12 ProMax. After 50 calls 12 emails 2 months 5 days still I do not have an invoice.
# What a great smart company is yours that drive customers crazy.
# Congratulations for your great efficiency.
# #iPhone
# #Apple
# #Appleinc
# #CustomerCare
# @CJamesKitto @Apple @AppleSupport Try out 'hubunlock' on Instagram to get it unlocked they helped me out with mine
# @AppleSupport I don't know what's going on with AirPods but they are hardly working after macOS 11.2.3. If I pause a video and come back to it, it will not play through my headphones. I have to disconnect them and reconnect them every time.
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger Now he's a neat trick, 2 media views despite zero impressions https://t.co/0a3ENlKpah
# @AppleSupport @Apple Replaced broken iPhone 6s and cannot continue setup b/c it won't connect to WiFi. Can Someone help or tell me where I can get it from?
# @AppleSupport Like, honestly. I should be able to workout in the winter without worrying about the sleeve stopping my workouts. It’s ridiculous. Or having to try and figure out how to “wear the watch differently.”
# @AppleSupport I’ve been dealing with issues on this watch for months. The agent is finally agreeing to bring it in for servicing. I’ve never been so disappointed in my interactions with Apple as I have been over this watch. 10 months of issues, and 10 months of dodging.
# @AppleSupport agent telling me to wear my Apple Watch differently in the winter, in Canada, because my Apple Watch touching the lining of my winter coat is PAUSING MY WORKOUTS.
# Is this normal after 4 months owning my new iPhone my battery health has gone to 96%
# WTF!
# @AppleSupport is this normal my old iPhone didn’t go down this fast! https://t.co/DjnWKqLtab
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# .@AppleSupport if you’re on an iphoneX done update to iOS 14.4.1. Messaging emotes is completely broken. How’d they miss this? Happening on both iPhone X’s. https://t.co/9J4nB7X29M
# @Apple I was VERY disappointed with @AppleSupport.  I have a very simple issue, but it’s like your techs do not understand the issue and are doing nothing about it.  I have 2 iPads that are exactly the same.  They were both purchased at the same time from the same store.
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger I warned them to stop with that incessant hacking and harassment. I'm not even going to bother re-sending these hacks that he blocked.. https://t.co/Y28NAKVjkZ
# @AppleSupport Maybe it’s due on the 3rd August though...
# @AppleSupport I’ve lost all the notes on my phone I logged out my emails and logged back in and nothings helping? My whole life’s on my notes I need them back pleaseeee
# @AppleSupport so you guys don’t put the adapter and the headphones in the boxes when you get a new phone?! As a long time  iPhone consumer I’m disappointed and I want to return my phone and go with @SamsungMobile
# &amp; I can’t even use my old one as you guys changed it to USB-C port
# @LuSchmoo @AppleSupport I know
# @AppleSupport The problem was solved thanks :)
# Hey @Apple @AppleSupport
#
# My cell phone is heating up, what do I do? 😕
# @AppleSupport Hi, I have an iPhone 7 and just accidentally deleted all my iMessages to and from a contact. I have messages saved in iCloud drive. How do I access them? Can I put them back on my phone?
# @AppleSupport Very disappointed that HomePod has died after only 3 years. I know it’s out of warranty but I would have expected more from a $500 speaker 😩
# @AppleSupport I was VERY disappointed with Apple Support.  I have a very simple issue, but it’s like your techs do not understand the issue and are doing nothing about it.  I have 2 iPads that are exactly the same.  They were both purchased at the same time from the same store.
# @AppleSupport This is amazing. Not only have my headphones that won’t connect to 5 different devices not been repaired, but now they are being delivered to my house in the past. They are apparently in transit and due to arrive last Monday morning. Your driver’s name is McFly. https://t.co/nAZ9kDQSsl
# I love that #AppleWatch 6 taps my wrist to wake me up every morning. A gentle touch. @Apple @AppleSupport 🥰♥️⌚️
# @AppleSupport i am once again asking you to fix the imessage problem on my macbook. why do i keep getting kicked out after i log in
# @AppleSupport please provide the contact for VP of operations for north America. Terrible Terrible Terrible experience
# @shanepryde20 @AppleSupport help
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @AppleSupport Perfect, that wasn’t helpful at all!
# @Apple @AppleSupport my sisters iPhone is stuck on Astart up loop with Apple logo.Tried everything to restart but don’t want to recovery mode &amp; lose the data.Can’t sign into iCloud as forgot password &amp; it’s sending help to the iPhone she can’t access &amp; account is now locked. HELP
# @AppleSupport this seems excessive for “Other” storage on my iPhone 7. Any tips or tricks for freeing up these resources? https://t.co/KxAj9V5Qi9
# @MadenaP @AppleSupport The cloudy screen could be a portal to another dimension. If so, I will be hunting for mine immediately.
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger HACKED Gboard
#
# You can see at 15 seconds he swaps screens as the download goes from 0% to over 50% and the "add language" option shows back u https://t.co/0nojiQZx96
# @AppleSupport I changed my email on my account, but the email showing on my phone is now the old email. I’m wondering if I log out, then log back in, will I still have all my info and purchases? https://t.co/OLdgVA0uNm
# Is there an accessible #a11y version of these instructions? @AppleSupport https://t.co/EL6cil1SIC
# @GabbieHanna @AppleSupport cancelled
# @AppleSupport 5 Row with numbers please,maybe when Snow in Florida
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger Hacker kept hacking my call to the IRS by turning the phone off speaker, blocking the audio on prompts or skipping prompts. He only stopped when I started recording the call but then hacked that app https://t.co/HZMkrSJnnU
# @AppleSupport I have a browser that I’ve deleted off my phone, and went to reinstall it from my Purchased list, but the Store page lists ‘Open’ as if it were still installed. [1/2]
# Time for a regular poke at @AppleSupport as over two years later the iOS stocks app still struggles with basic concepts of months. This time 2 x Jan 😂👍 https://t.co/Sg8LMGD73W
# @AppleSupport Maybe I’m wrong but I remember on iMessage I could use a normal emoji and paste it above text like sticker, does it still works? Because I couldn’t find it only for Memoji.
# @GoAstroMo @Apple @AppleSupport I'm your fellow folklorist/science chica.
# @HydroCycler @Apple @AppleSupport No problem 😊 Keeping my fingers crossed that keynote adds the feature 🤞🏽
# @AppleSupport Na, you deserve public shaming for lousy software and non-existent testing :)
# I tried importing a different memory card, and experienced the same error. How can I fix this? @AppleSupport 😌 https://t.co/gIfoewktlt
# What the fuck you can't save gifs anymore on iOS 14 @AppleSupport
# @GoAstroMo @Apple @AppleSupport Thanks so much for engaging. More things I had not considered fully enough.
# @AppleSupport
# Do not lose your brand value.Release 2 phones a year Do not do this 13 mini 13 13pro 13pro max.Your brand value is being lost. Be better than otherphones.add this feature. at the same time 3camara working option.focus locking options. add 20x more zooming options.
# @AppleSupport your apple care is not up to scratch
# @AppleSupport I’m furious that I’ve wasted a whole day because Apple makes poor courier choices!
# @AppleSupport Using the Apple SD card reader to import photos has not worked for a while. The import requires 6,62GB and as you can see I have 61,87GB available. The photos app says I need 4,1GB additional space to import. Tried the same on my girlfriends phone - same problem.. https://t.co/aPdjon14ff
# @AppleSupport failed to respond till this evening. Very disappointed with customer care I have received considering expense of Apple care. You should use a courier that takes pride in its service. I paid for quality care that I did not receive
# @AppleSupport It's an iPhone 12 Pro running iOS 14.4.1. I did the restart, but the weirdness is still there.
# Ugh the Music app on macOS sucks. It doesn't accept my own artwork @AppleSupport
# @AppleSupport why is this a problem!!! https://t.co/fcCGyTRFn6
# @HydroCycler @Apple @AppleSupport Yes! But also for people who find it easier to process written words over speech. And people who might be working through a language barrier. Lots of reasons to do it 😊
# @Vengefuleaglebv @AppleSupport And it’s a hell of a lot easier than having them on an external drive.
# Yesterday I visited to chroma and I saw macbook apple pro @Apple it was so amazing product I ever seen. But it was out of my budget. Even I can't afford to touch it. So I didn't touch but after looking to that I would say no match to that product. @AppleSupport
# Seems to be a general bug in Big Sur as I am not the only one having the problem... 🤔https://t.co/W5Q1aZ4KO2
#
# Very annoying! Please do something @AppleSupport !
# RT @hndami1: @tim_cook
# This is my case number : 101299632484 @Apple @AppStore @AppleSupport
# RT @hndami1: @tim_cook  Apple team said “ create a new iTunes account and go to any police station to report Apple then will refund your mo…
# RT @hndami1: @tim_cook Its been 6 months of calling long distance each call i have to wait more then an hour just to get a reply for my iss…
# @sameerrajakumar @AppleSupport Hello, this is perfect with normal as files need to finish indexing after an update. Give it about 24 to 48 hours after you complete an update and then the temperature should feel normal after that period.
# @AppleSupport Sloth 🦥 😂😂😂
# @GoAstroMo @Apple @AppleSupport The idea being for people deaf or hard of hearing?
# @AppleSupport Hi, I don't have anyone elses I can try. This is a known issue that's been discussed on your forums for a while. I have tried different USB outlets, cleaning the watch and charger, I have tried turning my watch off and on, I have tried using a wall outlet instead of usb.
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger Again, THIS is the kind of guy people are protecting for money, just a terrible human being aside from breaking his oath and abusing his power and being a criminal hacker for hire. https://t.co/pzwuErh43x
# @Comedydaddy @MadenaP @AppleSupport I was thinking the same. May take a while.
# as someone who is extremely petite &amp; small, @AppleSupport @AppleMusic @Apple can u send this to someone so they can consider making an iphone w a good camera/battery life/super light/one that can fit in my hands/pockets this size pls? maybe in time for christmas this yr? 😅🥺🙇🏼‍♂️✨ https://t.co/BUnCugkzeL
# @AppleSupport thanks for telling me my repair would take 3-5 days then 5 to 7 days but really telling me it will take two to three weeks. In 20 years of owning macs I have never 👎🏾 experienced such dismal service. Aside from that thanks for smashing my work schedule to pieces.
# @Apple @AppleSupport please consider adding a screen share feature to FaceTime. It would minimize the number of screenshots shared between those on FaceTime (there are a lot and I look ugly in all said screenshots). Thanks!
# @AppleSupport If you can respond publicly it would be helpful for many customers who are facing this issue.. @Apple
# @AppleSupport When I am done working and thank you
# @Apple  @AppleSupport this is getting out of hand, why is “Other” taking 20GB of my 32GB iPhone 7? https://t.co/8h7HRT6VcJ
# Hi @AppleSupport, having trouble getting my 2016 MBP 13" to recognize an Apple wired keyboard. Running Big Sur 11.2.2
# It still boggles me that 🇩🇰 doesn’t even have predictions on iPhone in 2021 🤯 @AppleSupport https://t.co/cwgavmX3ry
# @MadenaP @AppleSupport Let it fully charge?
# ⁦@AppleSupport⁩ HELP! Found my iPod after many years and plugged it in but a weird cloudy light displays! Is there any hope? I tried to “menu/middle button” and no logo is visible... 😭😭😭🤕🤕🤕 https://t.co/WiQZC7hitB
# @PrimleyJack @Apple @AppleSupport Thank you so much. Im useless with these things so I really appreciate this.
# HELP ME PLEASE @AppleSupport https://t.co/Uy6pQjvRj1
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# @AppleSupport Hello! I have a question about one of your products.
# @AppleSupport looks like the Photos widget doesn't support black and white photos ? I've never seen it go completely black. https://t.co/6LEvtU5WtN
# @AppleSupport Hi there, I Updated My Mac OS Big Sur last night and now my WIFI has completely stopped working, Ive tried all the usual fixes, is this a predominant problem with your software ????
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @Weezus420 @AppleSupport I literally think the same thing every time I use them. C’mon Apple!!
# @justmeCheal @Apple @AppleSupport Just do a search referencing your exact location.
# This is the sort of operation you need:
# https://t.co/rkEnTeYtzV
# Hey @AppleSupport @tim_cook almost one month that i have to work with a flickering #iphone12. Customer support : wait. It’s too long now. https://t.co/x2piDNw1UM
# 📈📉 What kind of stock graphs are these? I don’t know where to even begin here. @AppleSupport 👉🏼👌🏼 https://t.co/BZ7aMu3ya0
# @AppleSupport @Apple eh what?! https://t.co/BLmpMD5ltd
# @AppleSupport Please can you check the direct?
# @AppleSupport  how do I lower the other category? Already deleted Safari data and reduced iMessages to 30 days. Please help. https://t.co/7tP0GSiWqj
# @AppleSupport I’m on it. Thanks https://t.co/AzSvN2Z1Oc
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger He just shut down the Amazon Photo process and when I opened the app back up the videos he had been throttling so it takes forever to back up both had errors. It's obvious from the Hacker since he just turned off a running process https://t.co/8p4zpSB56Q
# @AppleSupport Damn y’all thought of everything.
# @PrimleyJack @Apple @AppleSupport Scottish borders.. Our nearest apple store is 90 miles away.
# @justmeCheal @Apple @AppleSupport So, a receipt is likely out of the question.
# 🤔
# You’re probably best to get an Apple-centric but independent boffin on it.
# Whereabouts in the country are you?
# RT @fred_royster: Another #MacOs #bigsur update and the snooze feature in notifications to choose whatever time you want to snooze for has…
# @E_mmanuelM @CarolKgafela @AppleSupport That’s the thing. I don’t want to lose the data
# @AppleSupport He only has an iPad Mini 2 running 12.5.1. Will this work?
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# @iNick_apple @YouTube @AppleSupport @Apple Super helpful. Thx @iNick_apple
# @Apple @AppleSupport anyway to get something quicker? Leaving on a trip would like it before I leave.
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger Started according to my schedule again. Throttling data to prevent backups and jamming data https://t.co/TqLGmZsYim
# Had a not-so-great experience with @AppleSupport in the wee hours of today while nursing a migraine.
#
# It felt like a conversation with a drone.
#
# Zero empathy
# Zero resolution
# @AppleSupport how do I get .git and Xcode workspaces to backup to iCloud Drive?
# @Ner1sa @AppleSupport Sorry to hear this. Let’s see what apple can do. For future check out @scribepay to manage all your subscriptions
# RT @AppleSupport: Search for an animal 🐧🦉🦩
# A feeling 😄🤗🥳
# Even a color 🚨🌶🌹
#
# Find the perfect way to express yourself. Here’s how to search f…
# .@AppleSupport turned off auto brightness on my Mac but it still automatically adjusts brightness. Pls help. I’m Not dumb 😤
# @AppleSupport It also bricked my external display. Can I please get some help?
# Hi @AppleSupport,
#
# I’ve restarted my phone. My bill is paid. I updated to most recent iOS just last night. Sporadic songs on my @AppleMusic are grayed and state “they’re not available in my region”.
#
# Send help! 🙏🏻
#
# Truthishly,
# Jordan
# @AppleSupport Yeah. I canceled on Saturday 3/6 and got charged TODAY, 3/9.
# @RachelTrue @Apple @AppleSupport Now, your story goes around the world (2 French media today)
# https://t.co/ItqqjNjCoR
# RT @fred_royster: Another #MacOs #bigsur update and the snooze feature in notifications to choose whatever time you want to snooze for has…
# @StefanGoldkuhle @AppleSupport Just create shortcuts and add the widget
# @AppleSupport just sent you guys a DM re. AppleCare - if someone can let me know, thanks!
# RT @RachelTrue: Can get your coders to free my last name from icloud jail?
# Been locked out for 6+ months because of an uncapitalized t in T…
# @AppleSupport hi, if you’re setting up a new iPad does it automatically download the apps etc that you have on your iPhone once you enter your Apple ID or can the content on the 2 devices be kept separate? Thanks
# Another #MacOs #bigsur update and the snooze feature in notifications to choose whatever time you want to snooze for has not been restored @AppleSupport
# @AppleSupport  this is my second iPhone 12 mini and it gets very hot when charging . What’s up ?
# @AppleSupport apple, honestly ur keyboard sux so much, its pain to use, i make many mistakes before i can type anyth. No row with numbers above, layout for any other language not EN is total disaster!!!
# @HydroCycler @Apple @AppleSupport Honestly, it’s new to me, too. But I want to start making it my default that my talks have captions
#
# On google slides, it’s as simple as clicking “Present” and then clicking the “cc” in the menu that pops up
#
# The captions aren’t perfect, but they’re better than nothing
# @AppleSupport I’m updated already and it’s still not working
# @PrimleyJack @Apple @AppleSupport Yeah it was my dads, he gave it to my daughter when he upgraded. Im not sure where he bought it.
# I wont be driving for a while yet unfortunately as still very early on in my recovery so it won’t be anytime soon sadly.
# @PumpkinBladeTV @AppleSupport Nah I will bully... I’m kidding
# @noaimneeded @AppleSupport Shut it or I bully
# ...
# Fellow #applewatch runners, anyone know what the grey dots mean? Loss of signal? ⁦@AppleSupport⁩ do you know? https://t.co/loqjeBjwEh
# @AppleSupport I’ve noticed I’m able to get into my iCloud account and store via my laptop but not my iPhone atm.
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# 6 weeks guys. 6 weeks. With all the back and forth. Yeah, just finally ran out of patience @AppleMusic @AppleSupport
# @Apple @AppleSupport apple device i need to restart bluetooth every time  to  still connecting !!!! What esteemed company is this @Huawei time to shifting after 10 years using apple devices https://t.co/m3wr6UAiJm
# @Apple @AppleSupport two brand new MacBook Air M1s purchased and delivered several weeks apart. BOTH SMELL MOLDY and your terrible advisers won’t help. It’s pathetic. @NBCNewsTech @HuffPostTech @techradar @Gizmodo
# @AppleSupport 1.  iPhone 12 mini     2.  iOS 14.4     3.  I’ve tried taking it off WiFi and used 5g and also have rebooted my device.
# RT @bobtiki: ⁦@AppleNews⁩ ⁦@AppleSupport⁩ How do I get the News app to stop showing me prompts to show news sources I have blocked? I block…
# @AppleSupport been put on hold for over an hour after being told I’d be called back today,  to then find they closed! Disgraceful service
# And this is after being bounced around by @AppleSupport over a period of 6 weeks and counting. Are we a joke to you guys @AppleMusic @Apple? Fix this!
# Why does @AppleSupport every 2 minutes switches a rep when texting/emailing on a case, &amp; playing dumb asking customers 2 spill the beans on their tech issue? What a lousy service 4 a wealthy company! @Apple I figure out the solution in moments compared 2 weeks by them, 🤔hire me?
# @Apple @AppleSupport should make an app where it give you only stores that have Apple Pay
# Is there actual @AppleSupport for @AppleMusic? With a real policy to support customers that they're legally contracted to? And not some silly corporate line like "we're not allowed to support you/your region"
# @AppleSupport I got a notice that I have 5 days left to trade in my iPhone. How about I supposed to do that when you haven't sent me the box to ship it back in???
# Hey @AppleSupport your latest iOS update is crashing on a current iPad almost every time I try and open a URL. This happens across browsers, and apps. What is a timeline for a fix? Seriously, this needs fixing....
# RT @AppleSupport: Get your friend’s attention in a group conversation. Mention them.
#
# Here’s how to mention someone in Messages for iPhone,…
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @AppleSupport Hi, had contacted before because my trade in was returned, no idea why the laptop in perfect condition outside of rubber feet. Also my new M1 MacBook Air having performance issues doing same thing as that 2014 pro - can you pleas help?
# @Apple who am I supposed to find my AirPods if they are in the case, and find my iPhone can not play the sound or have a current location?🤨 Can y’all find a solution to this problem please. @AppleSupport
# @AppleSupport It’s iOS14.4
# Wouldn’t it be nice if you could name files on iOS in the photos apps? I can’t be the only one that edits photos &amp; videos and gets confused with which is which. You can do it with the Files app, but not unless they are saved into something other than photos. @Apple @AppleSupport
# @mariahsblink @AppleSupport Well then keep complaining
# @AppleSupport  my iPhone 12 Pro silicone case is falling apart after only a few months of normal usage. Are you able to help me use the manufacturer’s warranty please?
# @AppleSupport Aye good looks gang
# @bramus @AppleSupport The bug doesn't affect other webkit browsers, though. Only Safari.
# @AppleSupport yo my AirPods never work https://t.co/yQsj8c16Bg
# @tim_cook @AppleSupport Can you make a short space grey keyboard and build a finger print reader into it? Thanks.
# @AppleSupport Thank you ‘ I am grateful but I live in Kenya!  Van you give me e-mail address please
# @AppleSupport can I give this to you or do you get 1000's? Here is the email address it came from:
#
# scureapplckdax28auwiappsueia78sy282919023-32136@andi37.scuredunlck.com https://t.co/IhrxziXTVD
# @AppleTV @AppleSupport hi. When I was looking at buying the Lord of the Rings extended version on Apple TV on my MBP it listed incorrect films. It says “Extended” but they’re the shorter versions as I see them in my library. How do I make them the Extended versions? https://t.co/LSrWkboUun
# @lemmk @AppleSupport Yes, same @AppleSupport. I can't send an email via Mail app on my laptop. Getting a message "Could not be moved to the mailbox 'iCloud.' Server returned the error. Server busy." And when I logged in via Chrome it said iCloud encountered an error when trying to connect to server.
# RT @jesgarrigan: Check out the new Apple for Kids support page to explore how to manage family sharing, set up your child’s device, and kee…
# @TrakinTech @RedmiIndia @AppleSupport  @tim_cook this is what we want
# @AppleSupport Hello,ive had this problem for a long time now and it's getting annoying.
# So I changed my apple id's email address a long time ago.
# I had a lot of problems with it but i managed to fix them except for one,i dont really know how to explain it but whenever i try to-
# @AppleSupport That's the problem. I'm forced to enable 2FA now because of the new policy. To do so, I need to enter my security questions, but I can't and I can't reset them either because it keeps telling me insufficient information
# @AppleSupport Thanks
# @AppleSupport Someone posing as Apple Support has called at least 7 times to my landline with a robo call..If I don't answer they leave a message. They say to return their call ar 315 232 8257. Surely this is illegal to harass someone like this! @Ask_Spectrum
# @applesupport are yall makin new games on the pippin
# RT @jesgarrigan: Check out the new Apple for Kids support page to explore how to manage family sharing, set up your child’s device, and kee…
# @AppleSupport Hi! I just got a sketchy email about my account using my email signing into a Mac. I don't own a Mac, so I went in and reset my password, and it says country/region Singapore.... I'm trying to change it but it's asking for payment info?
# @Apple I tried so many Times but I didn't get any response from Anyone..
# Then I decided to do this that Ask directly to you and tell you that how to get iphone 12 mini free ..?
# Can You please arrange me that cell phone For my future Study's..! @Apple @AppleSupport @AppleEDU
# @AppleSupport So basically wht feedback i got frm @Apple is, the lock screen behaviour is expected which means despite of using 12 hour clock @Apple #iPhone12Pro wont show it on lock screen! lol its better to remove it &amp; just give 24hrs! Big Salute to Creators of lock screen! #ios14homescreen
# Your silence is deafening @AppleSupport
# Hey @AppleSupport! Where is my #MacbookPro. It's been 4 weeks since @apple &amp; @FedEx lost it. You asked for 1,2,3,4, now a 5th week to "investigate". You didn't get a signature &amp; left it in a lobby my building doesn't have. What are you investigating. Where is my #MacBook ? https://t.co/I9uqqzNHxJ
# @AppleSupport Been using this for years
# @AppleSupport Yo, I wanna report someone who's abusing the apple refund algorithm from Roblox.
# @x71n3 @matthew_d_green Are you “listening” @AppleSupport ? BTW, the BT GUI is still terrible. Just a mess.
# Check out the new Apple for Kids support page to explore how to manage family sharing, set up your child’s device, and keep track of your child’s activity and usage! ⁦@AppleSupport⁩  https://t.co/2PrUaeWrSG
# @AppleSupport My note on iCloud suddenly just vanished and therefore had to redo my assignment question. Can you guys please fix this bug in notes app? This is not the first time happening.
# @AppleSupport No this is not the issue . You were able to choose the time you could snooze for..5,10,60 minutes it’s gone now
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @AppleSupport it seems to work without using the spacebar
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @AppleSupport I have gay Friends do they have a mental disorder ? @tim_cook use those Chinese death camps for profit bc Xi thinks you’re special https://t.co/ije8i1SidP
# @bmcbryer @AppleSupport @tim_cook has a mental disorder please don’t expect to much from apple https://t.co/ije8i1SidP
# .@AppleSupport I have an M1 Macbook Air that I bought in November and I continuously get this message when using #Safari about using significant memory.
#
# I'm running one window, no other tabs and no other applications. Should I be using #Chrome instead? What is the deal? https://t.co/lIKQwaeLqI
# @dentaku @MarkusBlaschke @Azure @AppleSupport The CEO @tim_cook has a mental disorder don’t expect anything from Apple https://t.co/ije8i1SidP
# @AppleSupport I’m just curious why a guy @tim_cook with a Mental Disorder is run the Company ? https://t.co/ije8i1SidP
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger So I decided to have Safari redirect me to the app store but was still suspicious. And sure enough the hacker cloned the app and was trying to get me to download it from a duplicate screen https://t.co/8GhFehBn5O
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @AppleSupport It’s not about being unable to download it. It‘s that the page loads completely unrelated images for some Victoria‘s Secret app before they are replaced with actual screenshots of the Azure app.
# @dananessel @AppleSupport @FBI @GovWhitmer @MIAttyGen @washingtonpost @WashTimes @FoxNews @SenGaryPeters @RepLawrence @FCC @FTC @JoeBiden @SpeakerPelosi @MichStatePolice @MichiganLEO @FBIDetroit @freep @detroitnews @FOX2News @KamalaHarris @Apple @TwitterSupport @briantylercohen @tim_cook @nytimes @AnaKasparian @cenkuygur @TYT @BernieSanders @MISupremeCourt @TomCottonAR @RepRaskin @RepKinzinger I've never had an app force an update otherwise it won't open before... https://t.co/7fSoFzTU0O
# @AppleSupport as you can my maps is not working so it’s my humble request to you to look into this matter https://t.co/Y3s5kB7kBx
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @AppleSupport Yes i shut it down then pressed the power button and then immediately pressed command + R still frozen on the apple logo with installation process 😭😭
# @AppleSupport I sent you a DM last week because one airpod pro earbud ($300 from @AmazonHelp) fell into a catch basin as I was shoveling snow. I warned that they don't stay in. Rather than providing a solution, you advised to suggestions for improvement. I want them replaced!
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @Apple @AppleSupport @tim_cook you really need to upgrade UI and UX on these 2 Apple apps: stocks and mail. Mail isn’t intuitive or have a great design like @gmail. #gmail has plenty of useful features like smart compose...
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @AppleSupport @Apple Does anyone check DMs, I didn’t want to embarrass anyone making my message public, but 10 days without replying DM is terrible, am I dealing with the real APPLE???
# A year into a #pandemic and the #iPhone still freaks out when you’re trying to unlock it while wearing a mask @AppleSupport
# @AppleSupport so in my junk mail there is calendar invites...I’ve not even opened the email and now they’re in my calendar and the decline apparently can’t be send to the sender? How can I stop this https://t.co/jzsYgyLvKK
# answer in dms if possible! @AppleSupport
# Dear @Apple @AppleSupport
# Exercise ring is not showing correct time. Please check.
# This is happening since last update on watch #applewatch #series5
#
# (Note:-Happened 2nd time this week) https://t.co/l7swPyEpXh
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @AppleSupport is there a way I can contact you about a return (Europe, France) without calling the phone number ? Email? Online form?
# Hey @Apple @AppleSupport, when can we start putting widgets anywhere we want on the Home Screen for iPad Pro just like on the iPhone? We have the technology, make it happen! #ipad #iphone #apple
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# Hey @AppleSupport I really would like to be able to tether my HomePod and my HomePod minis
#
# First world problems I know but it’s dumb that two like products don’t communicate
# @AppleSupport Thanks, but doesn't work. There is no "-" sign, and no option to "Delete App." That's the problem. All the icons wiggle, but no option to delete/remove.
# macOS 11.2.2 is way more aggressive in letting me know it can't reconnect to a local server
#
# every 5 seconds i get notified that it can't connect to a server that is currently offline &amp; unreachable
#
# @AppleSupport How can I tell it to stop bugging me? https://t.co/vHsitJrnBv
# RT @athenastevens: Hey @AppleSupport is there a way to change the ‘double click to pay’ feature. Those of us with disabilities affecting fi…
# @tim_cook You are the only one who can help me to recover photos from iCloud after 30 days. I know you have the way to do it. Photos are memorable for everyone and accidentally can happen every time. I need my photos come back. HELP ME PLEASE @AppleSupport
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# RT @AppleSupport: Complete. Cursor. Control.
#
# You can touch and hold the Space bar on your iPhone or iPad, and then drag your finger to mo…
# @AppleSupport Touch and hold anywhere on the keyboard and then little harder press to select text was so good with 3D Touch feature on previous iPhones..... missed those days 😢

# %%
df = pd.read_csv('tweet_reply_Apple.csv')  
df.to_csv('analyze_tweet_reply_Apple.csv', header = ['Comments'])

# %%
df1 = pd.read_csv('analyze_tweet_reply_Apple.csv')
df1.shape
# Out:
# (3999, 2)

# %%
import re
import string

def clean_text(text):
  text = re.sub('@[\w]*','',text)
  text = re.sub('\[.*?\]','',text)
  text = re.sub('[%s]'% re.escape(string.punctuation), '',text)
  text = re.sub('\w*\d\w*','',text)
  text= re.sub(r'@[A-Za-z0-9]+','',text) #remove mention
  text = re.sub('https?://[A-Za-z0-9./]+','',text) #remove https
  text = re.sub('b\w*','',text)
  return text

cleaned = lambda x: clean_text(x)

# %%
df1['Comments']= pd.DataFrame(df1.Comments.apply(cleaned))

# %%
df1
# Out:
#       Unnamed: 0                                           Comments
# 0              0    aftr taking any photo then going to my al to...
# 1              1   my dick i stuck in my mac us drive help me u ...
# 2              2   nHi since  hr  and I receive wrong activation...
# 3              3    Can get your coders to free my last name fro...
# 4              4          You know  still new to this phone so idk
# ...          ...                                                ...
# 3994        3994    Hey  is there a way to change the  click to ...
# 3995        3995   You are the only one who can help me to recov...
# 3996        3996    Complete Cursor Control nnYou can touch and ...
# 3997        3997    Complete Cursor Control nnYou can touch and ...
# 3998        3998   Touch and hold anywhere on the key and then l...
#
# [3999 rows x 2 columns]

# %%
df1 = df1.drop(["Unnamed: 0"], axis=1)
df1
# Out:
#                                                Comments
# 0       aftr taking any photo then going to my al to...
# 1      my dick i stuck in my mac us drive help me u ...
# 2      nHi since  hr  and I receive wrong activation...
# 3       Can get your coders to free my last name fro...
# 4             You know  still new to this phone so idk
# ...                                                 ...
# 3994    Hey  is there a way to change the  click to ...
# 3995   You are the only one who can help me to recov...
# 3996    Complete Cursor Control nnYou can touch and ...
# 3997    Complete Cursor Control nnYou can touch and ...
# 3998   Touch and hold anywhere on the key and then l...
#
# [3999 rows x 1 columns]

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading https://files.pythonhosted.org/packages/60/f0/1d9bfcc8ee6b83472ec571406bd0dd51c0e6330ff1a51b2d29861d389e85/textblob-0.15.3-py2.py3-none-any.whl (636kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\hp\anaconda3\lib\site-packages (from textblob) (3.4.5)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.15.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3

# %%
from textblob import TextBlob
import nltk
nltk.download('punkt')
nltk.download('brown')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def get_polarity(text):
  return TextBlob(text).sentiment.polarity

df1['TBpolarity'] = df1['Comments'].apply(get_polarity)

# %%
df1
# Out:
#                                                Comments  TBpolarity
# 0       aftr taking any photo then going to my al to...   -0.002083
# 1      my dick i stuck in my mac us drive help me u ...    0.000000
# 2      nHi since  hr  and I receive wrong activation...   -0.181818
# 3       Can get your coders to free my last name fro...    0.200000
# 4             You know  still new to this phone so idk     0.136364
# ...                                                 ...         ...
# 3994    Hey  is there a way to change the  click to ...    0.000000
# 3995   You are the only one who can help me to recov...    0.000000
# 3996    Complete Cursor Control nnYou can touch and ...    0.000000
# 3997    Complete Cursor Control nnYou can touch and ...    0.000000
# 3998   Touch and hold anywhere on the key and then l...    0.049167
#
# [3999 rows x 2 columns]

# %%
df1['Sentiment_type']= ''
df1.loc[df1.TBpolarity>0, 'Sentiment_type']='POSITIVE'
df1.loc[df1.TBpolarity==0, 'Sentiment_type']='NEUTRAL '
df1.loc[df1.TBpolarity<0, 'Sentiment_type']='NEGATIVE'
df1.head()
# Out:
#                                             Comments  TBpolarity  \
# 0    aftr taking any photo then going to my al to...   -0.002083
# 1   my dick i stuck in my mac us drive help me u ...    0.000000
# 2   nHi since  hr  and I receive wrong activation...   -0.181818
# 3    Can get your coders to free my last name fro...    0.200000
# 4          You know  still new to this phone so idk     0.136364
#
#   Sentiment_type
# 0       NEGATIVE
# 1       NEUTRAL
# 2       NEGATIVE
# 3       POSITIVE
# 4       POSITIVE

# %%
df1 = df1.drop_duplicates()

# %%
df1.shape
# Out:
# (2692, 3)

# %%
df1['Sentiment_type'].value_counts()
# Out:
# NEUTRAL     1187
# POSITIVE     887
# NEGATIVE     618
# Name: Sentiment_type, dtype: int64

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
sns.countplot(x ='Sentiment_type',data = df1).set_title('AppleSupport')
plt.show()

# %%
# Wordcloud libraries and Tweepy API
import sys
import string
import json
from collections import Counter
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import tweepy
from tweepy import OAuthHandler
from tweepy import Cursor

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
def word_cloud(wd_list):
    stopwords = set(STOPWORDS)
    all_words = ' '.join([text for text in wd_list])
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        width=1600,
        height=800,
        random_state=1,
        colormap='jet',
        max_words=80,
        max_font_size=200).generate(all_words)
    plt.figure(figsize=(12, 10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation="bilinear");
word_cloud(df1['Comments'])
