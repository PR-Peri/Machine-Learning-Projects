# %%
### Question 5 ~ Comparisions among Brands on Supports

# %%
import tweepy
from tweepy import OAuthHandler
import json
import csv
from tweepy import Cursor
import pandas as pd
import datetime
from datetime import timedelta
import time
import csv
import networkx as nx
from operator import itemgetter
import community #This is the python-louvain package we installed.
import matplotlib.pyplot as plt

# %%
# load/read from file using JSON
secrets = json.loads(open("secrets_Apple.json","r").read())

consumer_key = secrets['CONSUMER_KEY']
consumer_secret = secrets['CONSUMER_SECRET']
access_token = secrets['ACCESS_TOKEN_KEY']
access_token_secret = secrets['ACCESS_TOKEN_SECRET']


auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

#change per brand
screen_name = "AppleSupport"

# %%
def initialize():
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth, parser = tweepy.parsers.JSONParser())
    return api
api = initialize()

# %%
comp_searches = ("@AppleSupport", "@SamsungSupport", "@Moto_Support", "@XiaomiSupport" )

# %%
# Array to hold sentiment
sentiments = []
# Iterate through all the comp_searches
for search in comp_searches:
       
    # Bring out the 100 tweets
    comp_tweets = api.user_timeline(search, count=10000)
    
    # Loop through the 100 tweets
    for tweet in comp_tweets:
        text = tweet["text"]
        
     # Add each value to the appropriate array
        sentiments.append({"User": search,
                           "text":text,
                       "Date": tweet["created_at"] 
                        })

# %%
#convert array to dataframe
import pandas as pd
import numpy as np

df = pd.DataFrame.from_dict(sentiments)
df.head(5)
# Out:
#             User                                               text  \
# 0  @AppleSupport  @Jack_Deyes Great question, you can learn more...
# 1  @AppleSupport  @ldhca2003 Thanks for reaching out to us and w...
# 2  @AppleSupport  @1hqQneFHwgI8khw Thank you for the video. Plea...
# 3  @AppleSupport  @harrisdedon We know how important it is to ac...
# 4  @AppleSupport  @And123ChaCha123 We are here to help out and l...
#
#                              Date
# 0  Thu Mar 11 04:30:09 +0000 2021
# 1  Thu Mar 11 04:29:38 +0000 2021
# 2  Thu Mar 11 04:27:38 +0000 2021
# 3  Thu Mar 11 04:19:51 +0000 2021
# 4  Thu Mar 11 04:12:20 +0000 2021

# %%
#to see tweets for specific User name 
df_samsung = df[ df['User'] == '@SamsungSupport']
df_samsung.head()
# Out:
#                 User                                               text  \
# 200  @SamsungSupport  @AlfaVoland Hello, there! Just following up to...
# 201  @SamsungSupport  @Imryyann1 Hi, there! We have just replied to ...
# 202  @SamsungSupport  @DisguiseNarwhal Hi there! Welcome to our Supp...
# 203  @SamsungSupport  @megloops It was my pleasure, Mary! I wish you...
# 204  @SamsungSupport  @TnStriker Hi, there! Welcome to our Samsung s...
#
#                                Date
# 200  Thu Mar 11 12:53:22 +0000 2021
# 201  Thu Mar 11 12:39:17 +0000 2021
# 202  Thu Mar 11 12:35:38 +0000 2021
# 203  Thu Mar 11 12:22:32 +0000 2021
# 204  Thu Mar 11 12:06:40 +0000 2021

# %%
#cleaning the tweets
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)        
    return input_txt
def clean_tweets(tweets):
    #remove twitter Return handles (RT @xxx:)
    tweets = np.vectorize(remove_pattern)(tweets, "RT @[\w]*:") 
    
    #remove twitter handles (@xxx)
    tweets = np.vectorize(remove_pattern)(tweets, "@[\w]*")
    
    #remove URL links (httpxxx)
    tweets = np.vectorize(remove_pattern)(tweets, "https?://[A-Za-z0-9./]*")
    
    #remove special characters, numbers, punctuations (except for #)
    tweets = np.core.defchararray.replace(tweets, "[^a-zA-Z]", " ")
    
    return tweets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import tweepy
import re

df['text'] = clean_tweets(df['text'])
df['text'].head()
# Out:
# 0     Great question, you can learn more about the ...
# 1     Thanks for reaching out to us and we’d like t...
# 2     Thank you for the video. Please use the link ...
# 3     We know how important it is to access your in...
# 4     We are here to help out and look at additiona...
# Name: text, dtype: object

# %%
# pip install vaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
scores = []
# Declare variables for scores
compound_list = []
positive_list = []
negative_list = []
neutral_list = []
for i in range(df['text'].shape[0]):
#print(analyser.polarity_scores(sentiments_pd['text'][i]))
    compound = analyzer.polarity_scores(df['text'][i])["compound"]
    pos = analyzer.polarity_scores(df['text'][i])["pos"]
    neu = analyzer.polarity_scores(df['text'][i])["neu"]
    neg = analyzer.polarity_scores(df['text'][i])["neg"]
    
    scores.append({"Compound": compound,
                       "Positive": pos,
                       "Negative": neg,
                       "Neutral": neu
                  })

# %%
sentiments_score = pd.DataFrame.from_dict(scores)
df = df.join(sentiments_score)
df.head()
# Out:
#             User                                               text  \
# 0  @AppleSupport   Great question, you can learn more about the ...
# 1  @AppleSupport   Thanks for reaching out to us and we’d like t...
# 2  @AppleSupport   Thank you for the video. Please use the link ...
# 3  @AppleSupport   We know how important it is to access your in...
# 4  @AppleSupport   We are here to help out and look at additiona...
#
#                              Date  Compound  Positive  Negative  Neutral
# 0  Thu Mar 11 04:30:09 +0000 2021    0.6249     0.227       0.0    0.773
# 1  Thu Mar 11 04:29:38 +0000 2021    0.8236     0.399       0.0    0.601
# 2  Thu Mar 11 04:27:38 +0000 2021    0.5859     0.211       0.0    0.789
# 3  Thu Mar 11 04:19:51 +0000 2021    0.6983     0.243       0.0    0.757
# 4  Thu Mar 11 04:12:20 +0000 2021    0.4019     0.124       0.0    0.876

# %%
HT_positive = []
def hashtag_extract(x):
    hashtags = []
    # Loop over the words in the tweet
    for i in x:
        ht = re.findall(r"#(\w+)", i)
        hashtags.append(ht)
    return hashtags
# extracting hashtags from positive tweetsHT_positive = hashtag_extract(df_tws['text'][df_tws['sent'] == 1])
# extracting hashtags from  tweets
HT_positive = hashtag_extract(df['text'][df['Compound'] > 0.5])
# unnesting list
HT_positive = sum(HT_positive,[])
HT_positive
# Out:
# ['GalaxyS21',
#  'HelloMiFans',
#  'HelloMiFans',
#  'XiaomiSupportTips',
#  'MiQuiz',
#  'HelloMiFans',
#  'HelloMiFans',
#  'Miquiz',
#  'HelloMiFans',
#  '64663',
#  'MiFans',
#  'XiaomiSupport',
#  'NoMiWithoutYou']

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
def word_cloud(wd_list):
    stopwords = set(STOPWORDS)
    all_words = ' '.join([text for text in wd_list])
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        width=1600,
        height=800,
        random_state=1,
        colormap='jet',
        max_words=80,
        max_font_size=200).generate(all_words)
    plt.figure(figsize=(12, 10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation="bilinear");
word_cloud(df['text'])

# %%
#Collect the compound values for each news source
score_table = df.pivot_table(index='User',  values="Compound", aggfunc = np.mean)
score_table
# Out:
#                  Compound
# User
# @AppleSupport    0.590628
# @Moto_Support    0.442483
# @SamsungSupport  0.586484
# @XiaomiSupport   0.532108

# %%
score_table2 = df.pivot_table(index='User',  values="Negative", aggfunc = np.mean)
score_table2
# Out:
#                  Negative
# User
# @AppleSupport    0.006310
# @Moto_Support    0.025945
# @SamsungSupport  0.020290
# @XiaomiSupport   0.024365

# %%
score_table3 = df.pivot_table(index='User',  values="Positive", aggfunc = np.mean)
score_table3
# Out:
#                  Positive
# User
# @AppleSupport    0.254725
# @Moto_Support    0.198775
# @SamsungSupport  0.260790
# @XiaomiSupport   0.279185

# %%
score_table4 = df.pivot_table(index='User',  values="Neutral", aggfunc = np.mean)
score_table4
# Out:
#                  Neutral
# User
# @AppleSupport    0.73896
# @Moto_Support    0.77030
# @SamsungSupport  0.71893
# @XiaomiSupport   0.69644

# %%
#plotting 
g = score_table.plot(kind='bar',color="Green")
g2 =score_table2.plot(kind='bar',color="Blue")
g3 =score_table3.plot(kind='bar',color="Yellow")
g4 =score_table4.plot(kind='bar',color="Orange")
