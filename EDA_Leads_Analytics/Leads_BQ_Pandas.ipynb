# %% [markdown]
# # Average Leads- sum of leads / days-months
# # Leads per ad - sum of leads / ad id count

# %% [markdown]
# Do we have it?
#
# 1.   Which platform has highest Leads and Leads/Ad ratio
# 2.   Channel groupings (Leads and Leads/Ad ratio by platform)
# 3.   Which vertical has highest Leads/Ad ratio and Leads
# 4.   Seller type breakdown for each vertical
# 5.   Reply type breakdown for each vertical(Avg Leads only)
# 6.   Subcategory wise breakdown
# 7.   Region wise breakdown

# %%
import google.cloud.bigquery as bq
import pandas_gbq
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import plotly.io as pio

# %%
project_id = '.................'
click_type ='confirmed'

df1 = pd.read_gbq(
    """
          SELECT date,platform, sum(leads) as sumOfLeads 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" AND date<="2021-03-31")
          AND click_type=click_type 
          group by 1,2 
          order by 1
    """
, project_id = project_id)

df2 = pd.read_gbq(
    """
          SELECT date,platform, sum(leads) as sumOfLeads, 
          COUNT(DISTINCT(ad_id)) as ad_id 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          AND click_type=click_type
          group by 1,2 
          order by 1
    """
, project_id = project_id)

df3 = pd.read_gbq(
    """
          SELECT date,platform, channel_grouping, sum(leads) as sumOfLeads  
          FROM  `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          AND click_type=click_type 
          group by 1,2,3 
          order by 1
    """
, project_id = project_id)

df4 = pd.read_gbq(
    """
          SELECT date,platform, channel_grouping, sum(leads) as sumOfLeads, 
          COUNT(DISTINCT(ad_id)) as ad_id 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          and click_type=click_type 
          group by 1,2,3
          order by 1
    """
, project_id = project_id)

df5 = pd.read_gbq(
    """
          SELECT date,vertical, sum(leads) as sumOfLeads  
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          and click_type=click_type 
          group by 1,2 
          order by 
    """
, project_id = project_id)

df6 = pd.read_gbq(
    """
          SELECT date,vertical, sum(leads) as sumOfLeads, 
          COUNT(DISTINCT(ad_id)) as ad_id 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31")
          and click_type=click_type 
          group by 1,2 
          order by 1
     """
, project_id = project_id)

df7 = pd.read_gbq(
    """
          SELECT date,vertical,seller_type, sum(leads) as sumOfLeads 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          and click_type=click_type 
          group by 1,2,3 
          order by 1
    """
, project_id = project_id)

df8 = pd.read_gbq(
    """
          SELECT date,vertical,seller_type, sum(leads) as sumOfLeads, 
          COUNT(DISTINCT(ad_id)) as ad_id 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          and click_type=click_type 
          group by 1,2,3 
          order by 1
    """
, project_id = project_id)

df9 = pd.read_gbq(
    """
          SELECT date,vertical,reply_type, sum(leads) as sumOfLeads 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          and click_type=click_type 
          group by 1,2,3 
          order by 1
    """
, project_id = project_id)

df10 = pd.read_gbq(
    """
          SELECT date,subcategory, sum(leads) as sumOfLeads 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          and click_type=click_type 
          group by 1,2 
          order by 1
    """
, project_id = project_id)

df11 = pd.read_gbq(
    """
          SELECT date,subcategory, sum(leads) as sumOfLeads, 
          COUNT(DISTINCT(ad_id)) as ad_id 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          and click_type=click_type 
          group by 1,2 
          order by 1
    """
, project_id = project_id)

df12 = pd.read_gbq(
    """
          SELECT date,region, sum(leads) as sumOfLeads 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          and click_type=click_type 
          group by 1,2 
          order by 1
    """
, project_id = project_id)

df13 = pd.read_gbq(
    """
          SELECT date,region, sum(leads) as sumOfLeads, 
          COUNT(DISTINCT(ad_id)) as ad_id 
          FROM `'.................'` 
          WHERE (date >= "2020-07-01" and date<="2021-03-31") 
          and click_type=click_type 
          group by 1,2 
          order by 1
    """
, project_id = project_id)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=725825577420-unm2gnkiprugilg743tkbig250f4sfsj.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=53K92yc2I4zja0DPyr1EQcB2arrd1j&prompt=consent&access_type=offline
# Enter the authorization code: 4/1AY0e-g4rTIJquqPlW-15o9BlCe3CjbZZfkLrhfIoJ0bhJDkCCK5jC_kVxOM

# %%
df1['Year,month'] = pd.to_datetime(df1['date']).dt.strftime('%Y-%m')
df1['date'] = pd.to_datetime(df1['date'], errors='coerce')
df1['days_month'] = df1['date'].dt.daysinmonth
df1['year']= df1['date'].dt.year

df2['Year,month'] = pd.to_datetime(df2['date']).dt.strftime('%Y-%m')
df2['date'] = pd.to_datetime(df2['date'], errors='coerce')
df2['days_month'] = df2['date'].dt.daysinmonth
df2['year']= df2['date'].dt.year

df3['Year,month'] = pd.to_datetime(df3['date']).dt.strftime('%Y-%m')
df3['date'] = pd.to_datetime(df3['date'], errors='coerce')
df3['days_month'] = df3['date'].dt.daysinmonth
df3['year']= df3['date'].dt.year

df4['Year,month'] = pd.to_datetime(df4['date']).dt.strftime('%Y-%m')
df4['date'] = pd.to_datetime(df4['date'], errors='coerce')
df4['days_month'] = df4['date'].dt.daysinmonth
df4['year']= df4['date'].dt.year

df5['Year,month'] = pd.to_datetime(df5['date']).dt.strftime('%Y-%m')
df5['date'] = pd.to_datetime(df5['date'], errors='coerce')
df5['days_month'] = df5['date'].dt.daysinmonth
df5['year']= df5['date'].dt.year

df6['Year,month'] = pd.to_datetime(df6['date']).dt.strftime('%Y-%m')
df6['date'] = pd.to_datetime(df6['date'], errors='coerce')
df6['days_month'] = df6['date'].dt.daysinmonth
df6['year']= df6['date'].dt.year

df7['Year,month'] = pd.to_datetime(df7['date']).dt.strftime('%Y-%m')
df7['date'] = pd.to_datetime(df7['date'], errors='coerce')
df7['days_month'] = df7['date'].dt.daysinmonth
df7['year']= df7['date'].dt.year

df8['Year,month'] = pd.to_datetime(df8['date']).dt.strftime('%Y-%m')
df8['date'] = pd.to_datetime(df8['date'], errors='coerce')
df8['days_month'] = df8['date'].dt.daysinmonth
df8['year']= df8['date'].dt.year

df9['Year,month'] = pd.to_datetime(df9['date']).dt.strftime('%Y-%m')
df9['date'] = pd.to_datetime(df9['date'], errors='coerce')
df9['days_month'] = df9['date'].dt.daysinmonth
df9['year']= df9['date'].dt.year

df10['Year,month'] = pd.to_datetime(df10['date']).dt.strftime('%Y-%m')
df10['date'] = pd.to_datetime(df10['date'], errors='coerce')
df10['days_month'] = df10['date'].dt.daysinmonth
df10['year']= df10['date'].dt.year

df11['Year,month'] = pd.to_datetime(df11['date']).dt.strftime('%Y-%m')
df11['date'] = pd.to_datetime(df11['date'], errors='coerce')
df11['days_month'] = df11['date'].dt.daysinmonth
df11['year']= df11['date'].dt.year

df12['Year,month'] = pd.to_datetime(df12['date']).dt.strftime('%Y-%m')
df12['date'] = pd.to_datetime(df12['date'], errors='coerce')
df12['days_month'] = df12['date'].dt.daysinmonth
df12['year']= df12['date'].dt.year

df13['Year,month'] = pd.to_datetime(df13['date']).dt.strftime('%Y-%m')
df13['date'] = pd.to_datetime(df13['date'], errors='coerce')
df13['days_month'] = df13['date'].dt.daysinmonth
df13['year']= df13['date'].dt.year

# %%
df1 = df1.dropna()
df2 = df2.dropna()
df3 = df3.dropna()
df4 = df4.dropna()
df5 = df5.dropna()
df6 = df6.dropna()
df7 = df7.dropna()
df8 = df8.dropna()
df9 = df9.dropna()
df10 = df10.dropna()
df11 = df11.dropna()
df12 = df12.dropna()
df13 = df13.dropna()

# %%
df1['Avg_leads'] = (df1['sumOfLeads']/df1['days_month']) 
df1.head()
# Out:
#         date    platform  ...  year                      Avg_leads
# 0 2020-07-01         iOS  ...  2020  3207.851073793451612903225806
# 1 2020-07-01  Mobile Web  ...  2020  9184.222455851774193548387097
# 2 2020-07-01     Android  ...  2020  9906.432027862935483870967742
# 3 2020-07-01     Desktop  ...  2020  7157.307586257741935483870968
# 4 2020-07-02     Android  ...  2020  12042.52360613435483870967742
#
# [5 rows x 7 columns]

# %%
new1 = df1.groupby(['Year,month','platform']).agg({'Avg_leads': pd.Series.sum})
new1.to_csv('set1.csv')
plot1 = pd.read_csv('set1.csv')
plot1.head()
# Out:
#   Year,month    platform      Avg_leads
# 0    2020-07     Android  365736.508969
# 1    2020-07     Desktop  187926.252702
# 2    2020-07  Mobile Web  255275.627777
# 3    2020-07         iOS  105689.450777
# 4    2020-08     Android  375502.889615

# %%
fig = px.line(plot1, x="Year,month", y="Avg_leads", color="platform",color_discrete_sequence=px.colors.qualitative.Dark24,width =900,
              line_group="platform", hover_name="platform",title='Average Leads by monthly basis for platforms')
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b4959166-03f3-4d96-92b8-b7233d1494d0" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b4959166-03f3-4d96-92b8-b7233d1494d0")) {
#                     Plotly.newPlot(
#                         'b4959166-03f3-4d96-92b8-b7233d1494d0',
# ...

# %%
df2_1 =df2.groupby(['Year,month','platform']).agg({'ad_id': pd.Series.sum,'sumOfLeads': pd.Series.sum})

# %%
df2_1['Leads_per_ad']= (df2_1['sumOfLeads']/df2_1['ad_id'])
df2_1.head()
# Out:
#                          ad_id  ...                   Leads_per_ad
# Year,month platform             ...
# 2020-07    Android     1828186  ...  6.201683952309971195491049598
#            Desktop      950656  ...  6.128098737900199441227952067
#            Mobile Web  1160250  ...  6.820551140767326007326007326
#            iOS          562816  ...  5.821392735961523837275415056
# 2020-08    Android     1849439  ...  6.294119231869176004182890055
#
# [5 rows x 3 columns]

# %%
new2 = df2_1.groupby(['Year,month','platform']).agg({'Leads_per_ad': pd.Series.sum})
new2.to_csv('set2.csv')
plot2 = pd.read_csv('set2.csv')
plot2.head()
# Out:
#   Year,month    platform  Leads_per_ad
# 0    2020-07     Android      6.201684
# 1    2020-07     Desktop      6.128099
# 2    2020-07  Mobile Web      6.820551
# 3    2020-07         iOS      5.821393
# 4    2020-08     Android      6.294119

# %%
fig = px.line(plot2, x="Year,month", y="Leads_per_ad", color="platform",color_discrete_sequence=px.colors.qualitative.Dark24,title='Leads per ad by monthly basis for platforms',width =900,
              line_group="platform", hover_name="platform")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6c87c5a7-cfc7-4e7d-be4a-01f66f97a0aa" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6c87c5a7-cfc7-4e7d-be4a-01f66f97a0aa")) {
#                     Plotly.newPlot(
#                         '6c87c5a7-cfc7-4e7d-be4a-01f66f97a0aa',
# ...

# %%
df3['Avg_leads'] = (df3['sumOfLeads']/df3['days_month'])

# %%
df3.groupby(['Year,month','channel_grouping','platform']).agg({'Avg_leads': pd.Series.sum})
# Out:
#                                                             Avg_leads
# Year,month channel_grouping platform
# 2020-07    (Other)          Android     108546.6183059059032258064516
#                             Desktop     9420.363808847064516129032257
#                             Mobile Web  9461.785967662354838709677419
#                             iOS         142.0512037501612903225806453
#            Direct           Android     142176.5163435080967741935483
# ...                                                               ...
# 2021-03    Referral         Android     30.41888489509677419354838709
#                             Desktop     5670.159466877387096774193549
#                             Mobile Web  7033.918027963258064516129032
#            Social           Desktop     453.6612205728064516129032259
#                             Mobile Web  724.5575768955483870967741934
#
# [232 rows x 1 columns]

# %%
match = ['Android', 'iOS']
def string_finder(row, words):
    if any(word in field for field in row for word in words):
        return 'App'
    return 'Web'
df3['platformAPP'] = df3.astype(str).apply(string_finder, words=match, axis=1)
df3
# Out:
#            date    platform  ...                       Avg_leads platformAPP
# 0    2020-07-01  Mobile Web  ...  0.9721693165161290322580645161         Web
# 1    2020-07-01     Android  ...  0.8407791772903225806451612903         App
# 2    2020-07-01  Mobile Web  ...   1127.999177904258064516129032         Web
# 3    2020-07-01     Android  ...   5396.543732522483870967741935         App
# 4    2020-07-01  Mobile Web  ...   65.74088045319354838709677419         Web
# ...         ...         ...  ...                             ...         ...
# 7036 2021-03-31     Android  ...   126.6489879262903225806451613         App
# 7037 2021-03-31  Mobile Web  ...   140.1952301744838709677419355         Web
# 7038 2021-03-31  Mobile Web  ...   16.09089315606451612903225806         Web
# 7039 2021-03-31     Android  ...   7316.330636559483870967741935         App
# 7040 2021-03-31         iOS  ...   1798.833983548387096774193548         App
#
# [6673 rows x 9 columns]

# %%
Web = df3[df3['platformAPP']=='Web']
App = df3[df3['platformAPP']=='App']

# %%
new3_1 = Web.groupby(['Year,month','channel_grouping']).agg({'Avg_leads': pd.Series.sum})
new3_1.to_csv('set3_1.csv')
plot3_1 = pd.read_csv('set3_1.csv')

new3_2 = App.groupby(['Year,month','channel_grouping']).agg({'Avg_leads': pd.Series.sum})
new3_2.to_csv('set3_2.csv')
plot3_2 = pd.read_csv('set3_2.csv')

# %%
fig = px.bar(plot3_1, x="Year,month", y="Avg_leads", color="channel_grouping",color_discrete_sequence=px.colors.qualitative.Dark2, title='Channel Grouping by Web and Average Leads',width =900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8db49711-828b-4597-962c-faafe2528231" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8db49711-828b-4597-962c-faafe2528231")) {
#                     Plotly.newPlot(
#                         '8db49711-828b-4597-962c-faafe2528231',
# ...

# %%
fig = px.bar(plot3_2, x="Year,month", y="Avg_leads", color="channel_grouping",color_discrete_sequence=px.colors.qualitative.Dark2,width =900,title='Channel Grouping by Application and Average Leads')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e25654b2-e740-4edd-a81f-2efd127086b5" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e25654b2-e740-4edd-a81f-2efd127086b5")) {
#                     Plotly.newPlot(
#                         'e25654b2-e740-4edd-a81f-2efd127086b5',
# ...

# %%
df44 =df4.copy()

# %%
match2 = ['Android', 'iOS']
def string_finder(row, words):
    if any(word in field for field in row for word in words):
        return 'App'
    return 'Web'
df44['platformAPP'] = df44.astype(str).apply(string_finder, words=match2, axis=1)

# %%
df4_1 =df44.groupby(['Year,month','platform','channel_grouping','platformAPP']).agg({'ad_id': pd.Series.sum,'sumOfLeads': pd.Series.sum})

# %%
df4_1['Leads_per_ad']= (df4_1['sumOfLeads']/df4_1['ad_id'])
df4_1.to_csv('setdf4-1.csv')
newdf4 = pd.read_csv('setdf4-1.csv')

# %%
# Web = newdf4[newdf4['platformAPP']=='Web']
# App = newdf4[newdf4['platformAPP']=='App']

# %%
match2 = ['Android', 'iOS']
def string_finder(row, words):
    if any(word in field for field in row for word in words):
        return 'App'
    return 'Web'
df4['platformAPP'] = df4.astype(str).apply(string_finder, words=match2, axis=1)

# %%
Web1 = newdf4[newdf4['platformAPP']=='Web']
App1 = newdf4[newdf4['platformAPP']=='App']

# %%
new3_3 = Web1.groupby(['Year,month','channel_grouping']).agg({'Leads_per_ad': pd.Series.sum})
new3_3.to_csv('set3_3.csv')
plot3_3 = pd.read_csv('set3_3.csv')

new3_4 = App1.groupby(['Year,month','channel_grouping']).agg({'Leads_per_ad': pd.Series.sum})
new3_4.to_csv('set3_4.csv')
plot3_4 = pd.read_csv('set3_4.csv')

# %%
fig = px.bar(plot3_3, x="Year,month", y="Leads_per_ad", color="channel_grouping",color_discrete_sequence=px.colors.qualitative.Safe,width =900,title='Channel Grouping by Web and Leads per Ad')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1553ddc8-1dc6-4d08-8325-12aa0c98367f" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1553ddc8-1dc6-4d08-8325-12aa0c98367f")) {
#                     Plotly.newPlot(
#                         '1553ddc8-1dc6-4d08-8325-12aa0c98367f',
# ...

# %%
fig = px.bar(plot3_4, x="Year,month", y="Leads_per_ad", color="channel_grouping",color_discrete_sequence=px.colors.qualitative.Safe,width =900,title='Channel Grouping by Application and Leads per Ad')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7328b1e3-332b-4166-aff1-26c701ee9029" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7328b1e3-332b-4166-aff1-26c701ee9029")) {
#                     Plotly.newPlot(
#                         '7328b1e3-332b-4166-aff1-26c701ee9029',
# ...

# %%
df5['Avg_leads'] = (df5['sumOfLeads']/df5['days_month'])

# %%
new5 = df5.groupby(['Year,month','vertical']).agg({'Avg_leads': pd.Series.sum})
new5.to_csv('set5.csv')
plot5 = pd.read_csv('set5.csv')

# %%
fig = px.line(plot5, x="Year,month", y="Avg_leads", color="vertical",color_discrete_sequence=px.colors.qualitative.Set1,width =900,title='Average leads by monthly basis for Vertical',
              line_group="vertical", hover_name="vertical")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="be0a4964-3424-43bc-b2a2-0fc7afac89ae" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("be0a4964-3424-43bc-b2a2-0fc7afac89ae")) {
#                     Plotly.newPlot(
#                         'be0a4964-3424-43bc-b2a2-0fc7afac89ae',
# ...

# %%
df66 =df6.copy()

# %%
df6_1 =df66.groupby(['Year,month','vertical']).agg({'ad_id': pd.Series.sum,'sumOfLeads': pd.Series.sum})

# %%
df6_1['Leads_per_ad']= (df6_1['sumOfLeads']/df6_1['ad_id'])
df6_1.to_csv('setdf6-1.csv')
newdf6 = pd.read_csv('setdf6-1.csv')

# %%
new6 = newdf6.groupby(['Year,month','vertical']).agg({'Leads_per_ad': pd.Series.mean})
new6.to_csv('set6.csv')
plot6 = pd.read_csv('set6.csv')

# %%
fig = px.line(plot6, x="Year,month", y="Leads_per_ad", color="vertical",color_discrete_sequence=px.colors.qualitative.Set1,width =900, title='Leads per ad by monthly basis for Vertical',
              line_group="vertical", hover_name="vertical")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1b0a81c3-c8f9-4753-a6e2-cf42ce74a9bc" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b0a81c3-c8f9-4753-a6e2-cf42ce74a9bc")) {
#                     Plotly.newPlot(
#                         '1b0a81c3-c8f9-4753-a6e2-cf42ce74a9bc',
# ...

# %%
df7['Avg_leads'] = (df7['sumOfLeads']/df7['days_month'])

# %%
auto = df7[df7['vertical']=='Auto']
generalist = df7[df7['vertical']=='Generalist']
jobs = df7[df7['vertical']=='Jobs']
services = df7[df7['vertical']=='Services']
property = df7[df7['vertical']=='Property']

# %%
new7_1 = auto.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_1.to_csv('set7_1.csv')
plot7_1 = pd.read_csv('set7_1.csv')

new7_2 = generalist.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_2.to_csv('set7_2.csv')
plot7_2 = pd.read_csv('set7_2.csv')

new7_3 = jobs.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_3.to_csv('set7_3.csv')
plot7_3 = pd.read_csv('set7_3.csv')

new7_4 = services.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_4.to_csv('set7_4.csv')
plot7_4 = pd.read_csv('set7_4.csv')

new7_5 = property.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_5.to_csv('set7_5.csv')
plot7_5 = pd.read_csv('set7_5.csv')

# %%
fig = px.line(plot7_1, x="Year,month", y="Avg_leads", color="seller_type",  width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6cf961e4-7f82-4959-badb-1e90de276690" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6cf961e4-7f82-4959-badb-1e90de276690")) {
#                     Plotly.newPlot(
#                         '6cf961e4-7f82-4959-badb-1e90de276690',
# ...

# %%
fig = px.line(plot7_2, x="Year,month", y="Avg_leads", color="seller_type", width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e380d472-973f-47c0-a09f-e1f93476118d" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e380d472-973f-47c0-a09f-e1f93476118d")) {
#                     Plotly.newPlot(
#                         'e380d472-973f-47c0-a09f-e1f93476118d',
# ...

# %%
fig = px.line(plot7_3, x="Year,month", y="Avg_leads", color="seller_type", width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="62eb0f8d-a362-4478-b7e9-5bbec05ab635" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("62eb0f8d-a362-4478-b7e9-5bbec05ab635")) {
#                     Plotly.newPlot(
#                         '62eb0f8d-a362-4478-b7e9-5bbec05ab635',
# ...

# %%
fig = px.line(plot7_4, x="Year,month", y="Avg_leads", color="seller_type", width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4de1e91d-a6d0-4fea-8724-4d4f2aa647a3" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4de1e91d-a6d0-4fea-8724-4d4f2aa647a3")) {
#                     Plotly.newPlot(
#                         '4de1e91d-a6d0-4fea-8724-4d4f2aa647a3',
# ...

# %%
fig = px.line(plot7_5, x="Year,month", y="Avg_leads", color="seller_type", width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fddc561e-f03e-4b71-b061-3730e11ac37f" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fddc561e-f03e-4b71-b061-3730e11ac37f")) {
#                     Plotly.newPlot(
#                         'fddc561e-f03e-4b71-b061-3730e11ac37f',
# ...

# %%
df88 =df8.copy()

# %%
df8_1 =df88.groupby(['Year,month','vertical','seller_type']).agg({'ad_id': pd.Series.sum,'sumOfLeads': pd.Series.sum})

# %%
df8_1['Leads_per_ad']= (df8_1['sumOfLeads']/df8_1['ad_id'])
df8_1.to_csv('setdf8-1.csv')
newdf8 = pd.read_csv('setdf8-1.csv')

# %%
auto1 = newdf8[newdf8['vertical']=='Auto']
generalist1 = newdf8[newdf8['vertical']=='Generalist']
jobs1 = newdf8[newdf8['vertical']=='Jobs']
services1 = newdf8[newdf8['vertical']=='Services']
property1 = newdf8[newdf8['vertical']=='Property']

# %%
new8_1 = auto1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_1.to_csv('set8_1.csv')
plot8_1 = pd.read_csv('set8_1.csv')

new8_2 = generalist1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_2.to_csv('set8_2.csv')
plot8_2 = pd.read_csv('set8_2.csv')

new8_3 = jobs1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_3.to_csv('set8_3.csv')
plot8_3 = pd.read_csv('set8_3.csv')

new8_4 = services1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_4.to_csv('set8_4.csv')
plot8_4 = pd.read_csv('set8_4.csv')

new8_5 = property1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_5.to_csv('set8_5.csv')
plot8_5 = pd.read_csv('set8_5.csv')

# %%
fig = px.line(plot8_1, x="Year,month", y="Leads_per_ad", color="seller_type",width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="be65749a-5576-421a-8641-2ca4a5aa579a" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("be65749a-5576-421a-8641-2ca4a5aa579a")) {
#                     Plotly.newPlot(
#                         'be65749a-5576-421a-8641-2ca4a5aa579a',
# ...

# %%
fig = px.line(plot8_2, x="Year,month", y="Leads_per_ad", color="seller_type",width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8f71b358-4aec-4fef-89a8-a75c77b4845f" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f71b358-4aec-4fef-89a8-a75c77b4845f")) {
#                     Plotly.newPlot(
#                         '8f71b358-4aec-4fef-89a8-a75c77b4845f',
# ...

# %%
fig = px.line(plot8_3, x="Year,month", y="Leads_per_ad", color="seller_type",width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2fcc2781-9f10-41b5-96ee-7e4494cdd2cd" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fcc2781-9f10-41b5-96ee-7e4494cdd2cd")) {
#                     Plotly.newPlot(
#                         '2fcc2781-9f10-41b5-96ee-7e4494cdd2cd',
# ...

# %%
fig = px.line(plot8_4, x="Year,month", y="Leads_per_ad", color="seller_type",width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6cf0b473-70d3-47d0-9c8d-d9f2f7e913c4" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6cf0b473-70d3-47d0-9c8d-d9f2f7e913c4")) {
#                     Plotly.newPlot(
#                         '6cf0b473-70d3-47d0-9c8d-d9f2f7e913c4',
# ...

# %%
fig = px.line(plot8_5, x="Year,month", y="Leads_per_ad", color="seller_type",width =900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="043213a5-cd46-423e-86f1-56b07fc725dc" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("043213a5-cd46-423e-86f1-56b07fc725dc")) {
#                     Plotly.newPlot(
#                         '043213a5-cd46-423e-86f1-56b07fc725dc',
# ...

# %%
df9['Avg_leads'] = (df9['sumOfLeads']/df9['days_month'])

# %%
new9 = df9.groupby(['Year,month','vertical']).agg({'Avg_leads': pd.Series.sum})
new9.to_csv('set9.csv')
plot9 = pd.read_csv('set9.csv')

# %%
auto2 = df9[df9['vertical']=='Auto']
generalist2 = df9[df9['vertical']=='Generalist']
jobs2 = df9[df9['vertical']=='Jobs']
services2 = df9[df9['vertical']=='Services']
property2 = df9[df9['vertical']=='Property']

# %%
new9_1 = auto2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_1.to_csv('set9_1.csv')
plot9_1 = pd.read_csv('set9_1.csv')

new9_2 = generalist2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_2.to_csv('set9_2.csv')
plot9_2 = pd.read_csv('set9_2.csv')

new9_3 = jobs2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_3.to_csv('set9_3.csv')
plot9_3 = pd.read_csv('set9_3.csv')

new9_4 = services2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_4.to_csv('set9_4.csv')
plot9_4 = pd.read_csv('set9_4.csv')

new9_5 = property2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_5.to_csv('set9_5.csv')
plot9_5 = pd.read_csv('set9_5.csv')

# %%
fig = px.bar(plot9_1, x="Year,month", y="Avg_leads", color="reply_type",color_discrete_sequence=px.colors.qualitative.Dark24,width =900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="134f028c-b3b3-4733-9379-3f44e25a6b0e" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("134f028c-b3b3-4733-9379-3f44e25a6b0e")) {
#                     Plotly.newPlot(
#                         '134f028c-b3b3-4733-9379-3f44e25a6b0e',
# ...

# %%
fig = px.bar(plot9_2, x="Year,month", y="Avg_leads", color="reply_type",color_discrete_sequence=px.colors.qualitative.Dark24,width =900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0d2e59e7-c661-4ad4-9636-d7eb3b767ddc" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0d2e59e7-c661-4ad4-9636-d7eb3b767ddc")) {
#                     Plotly.newPlot(
#                         '0d2e59e7-c661-4ad4-9636-d7eb3b767ddc',
# ...

# %%
fig = px.bar(plot9_3, x="Year,month", y="Avg_leads", color="reply_type",width =900,color_discrete_sequence=px.colors.qualitative.Dark24)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5a5ac405-e601-4c8e-96ee-ae5dcc99ade6" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5a5ac405-e601-4c8e-96ee-ae5dcc99ade6")) {
#                     Plotly.newPlot(
#                         '5a5ac405-e601-4c8e-96ee-ae5dcc99ade6',
# ...

# %%
fig = px.bar(plot9_4, x="Year,month", y="Avg_leads", color="reply_type",width =900,color_discrete_sequence=px.colors.qualitative.Dark24)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6600a270-1844-4b60-8c35-598ec85536b9" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6600a270-1844-4b60-8c35-598ec85536b9")) {
#                     Plotly.newPlot(
#                         '6600a270-1844-4b60-8c35-598ec85536b9',
# ...

# %%
fig = px.bar(plot9_5, x="Year,month", y="Avg_leads", color="reply_type",width =900,color_discrete_sequence=px.colors.qualitative.Dark24)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="489f6b9e-9a17-4af9-8e75-fc0812b789d7" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("489f6b9e-9a17-4af9-8e75-fc0812b789d7")) {
#                     Plotly.newPlot(
#                         '489f6b9e-9a17-4af9-8e75-fc0812b789d7',
# ...

# %%
df10['Avg_leads'] = (df10['sumOfLeads']/df10['days_month'])

# %%
new10 = df10.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10.to_csv('set10.csv')
plot10 = pd.read_csv('set10.csv')

# %%
apart = df10[df10['subcategory']=='Apartments']
car = df10[df10['subcategory']=='Cars']
house = df10[df10['subcategory']=='Houses']

text = df10[df10['subcategory']=='Textbooks']
tick = df10[df10['subcategory']=='Tickets & Vouchers']
wedd = df10[df10['subcategory']=='Wedding']

# %%
new10_1 = apart.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_1.to_csv('set10_1.csv')
plot10_1 = pd.read_csv('set10_1.csv')

new10_2 = car.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_2.to_csv('set10_2.csv')
plot10_2 = pd.read_csv('set10_2.csv')

new10_3 = house.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_3.to_csv('set10_3.csv')
plot10_3 = pd.read_csv('set10_3.csv')

new10_4 = text.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_4.to_csv('set10_4.csv')
plot10_4 = pd.read_csv('set10_4.csv')

new10_5 = tick.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_5.to_csv('set10_5.csv')
plot10_5 = pd.read_csv('set10_5.csv')

new10_6 = wedd.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_6.to_csv('set10_6.csv')
plot10_6 = pd.read_csv('set10_6.csv')

# %%
# fig = px.line(plot10_5, x="Year,month", y="Avg_leads", color="subcategory",title = 'Subcategory based on Average Leads - Ticket & Vouchers',
#             line_group="subcategory", hover_name="subcategory",color_discrete_sequence=['light blue'])
# fig.update_traces(mode='markers+lines')
# fig.show()

# %%
import plotly.express as px
subcategory = plot10['subcategory']
labels=subcategory[:43]
for category in subcategory[:43]:
    df_b=plot10[plot10['subcategory']==category]    
    fig=px.line(df_b, x="Year,month", y="Avg_leads",labels="subcategory",width =900,color_discrete_sequence=['light blue']) 
    print(category) 
    fig.update_traces(mode='markers+lines')   
    fig.show()
# Out:
# Accessories for Phones & Gadgets
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4ba2ea43-cb93-4f01-af98-2e0deda44099" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4ba2ea43-cb93-4f01-af98-2e0deda44099")) {
#                     Plotly.newPlot(
#                         '4ba2ea43-cb93-4f01-af98-2e0deda44099',
# ...

# %%
df11 =df11.copy()

# %%
df11_1 =df11.groupby(['Year,month','subcategory']).agg({'ad_id': pd.Series.sum,'sumOfLeads': pd.Series.sum})

# %%
df11_1['Leads_per_ad']= (df11_1['sumOfLeads']/df11_1['ad_id'])
df11_1.to_csv('setdf11-1.csv')
newdf11 = pd.read_csv('setdf11-1.csv')

# %%
apart1 = newdf11[newdf11['subcategory']=='Apartments']
car1 = newdf11[newdf11['subcategory']=='Cars']
house1 = newdf11[newdf11['subcategory']=='Houses']

text1 = newdf11[newdf11['subcategory']=='Textbooks']
tick1 = newdf11[newdf11['subcategory']=='Tickets & Vouchers']
wedd1 = newdf11[newdf11['subcategory']=='Wedding']

# %%
new11_1 = apart1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_1.to_csv('set11_1.csv')
plot11_1 = pd.read_csv('set11_1.csv')

new11_2 = car1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_2.to_csv('set11_2.csv')
plot11_2 = pd.read_csv('set11_2.csv')

new11_3 = house1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_3.to_csv('set11_3.csv')
plot11_3 = pd.read_csv('set11_3.csv')

new11_4 = text1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_4.to_csv('set11_4.csv')
plot11_4 = pd.read_csv('set11_4.csv')

new11_5 = tick1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_5.to_csv('set11_5.csv')
plot11_5 = pd.read_csv('set11_5.csv')

new11_6 = wedd1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_6.to_csv('set11_6.csv')
plot11_6 = pd.read_csv('set11_6.csv')

# %%
subcategory = newdf11['subcategory']
labels=subcategory[:43]
for category in subcategory[:43]:
    df_b1=newdf11[newdf11['subcategory']==category]    
    fig=px.line(df_b1, x="Year,month", y="Leads_per_ad",labels="subcategory",width =900,color_discrete_sequence=['light blue']) 
    print(category) 
    fig.update_traces(mode='markers+lines')   
    fig.show()
# Out:
# Accessories for Phones & Gadgets
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="68fa9880-d6e2-4689-adbb-d963ca112b34" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("68fa9880-d6e2-4689-adbb-d963ca112b34")) {
#                     Plotly.newPlot(
#                         '68fa9880-d6e2-4689-adbb-d963ca112b34',
# ...

# %%
df12['Avg_leads'] = (df12['sumOfLeads']/df12['days_month'])

# %%
new12 = df12.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12.to_csv('set12.csv')
plot12 = pd.read_csv('set12.csv')

# %%
kl = df12[df12['region']=='Kuala Lumpur']
slg = df12[df12['region']=='Selangor']
jhr = df12[df12['region']=='Johor']

lab = df12[df12['region']=='Labuan']
per = df12[df12['region']=='Perlis']
put = df12[df12['region']=='Putrajaya']

# %%
new12_1 = kl.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_1.to_csv('set12_1.csv')
plot12_1 = pd.read_csv('set12_1.csv')

new12_2 = slg.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_2.to_csv('set12_2.csv')
plot12_2 = pd.read_csv('set12_2.csv')

new12_3 = jhr.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_3.to_csv('set12_3.csv')
plot12_3 = pd.read_csv('set12_3.csv')

new12_4 = lab.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_4.to_csv('set12_4.csv')
plot12_4 = pd.read_csv('set12_4.csv')

new12_5 = per.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_5.to_csv('set12_5.csv')
plot12_5 = pd.read_csv('set12_5.csv')

new12_6 = put.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_6.to_csv('set12_6.csv')
plot12_6 = pd.read_csv('set12_6.csv')

# %%
region = plot12['region']
labels=region[:16]
for regions in region[:16]:
    df_b2=plot12[plot12['region']==regions]    
    fig=px.line(df_b2, x="Year,month", y="Avg_leads",labels="region",width =900,color_discrete_sequence=['light blue']) 
    print(regions)
    fig.update_traces(mode='markers+lines')
    
    fig.show()
# Out:
# Johor
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="30e0c854-c60f-4676-9102-4483deea4067" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("30e0c854-c60f-4676-9102-4483deea4067")) {
#                     Plotly.newPlot(
#                         '30e0c854-c60f-4676-9102-4483deea4067',
# ...

# %%
df13 =df13.copy()

# %%
df13_1 =df13.groupby(['Year,month','region']).agg({'ad_id': pd.Series.sum,'sumOfLeads': pd.Series.sum})

# %%
df13_1['Leads_per_ad']= (df13_1['sumOfLeads']/df13_1['ad_id'])
df13_1.to_csv('setdf13-1.csv')
newdf13 = pd.read_csv('setdf13-1.csv')

# %%
kl1 = newdf13[newdf13['region']=='Kuala Lumpur']
slg1 = newdf13[newdf13['region']=='Selangor']
jhr1 = newdf13[newdf13['region']=='Johor']

lab1 = newdf13[newdf13['region']=='Labuan']
per1 = newdf13[newdf13['region']=='Perlis']
put1 = newdf13[newdf13['region']=='Putrajaya']

# %%
new13_1 = kl1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_1.to_csv('set13_1.csv')
plot13_1 = pd.read_csv('set13_1.csv')

new13_2 = slg1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_2.to_csv('set13_2.csv')
plot13_2 = pd.read_csv('set13_2.csv')

new13_3 = jhr1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_3.to_csv('set13_3.csv')
plot13_3 = pd.read_csv('set13_3.csv')

new13_4 = lab1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_4.to_csv('set13_4.csv')
plot13_4 = pd.read_csv('set13_4.csv')

new13_5 = per1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_5.to_csv('set13_5.csv')
plot13_5 = pd.read_csv('set13_5.csv')

new13_6 = put1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_6.to_csv('set13_6.csv')
plot13_6 = pd.read_csv('set13_6.csv')

# %%
region = newdf13['region']
labels=region[:16]
for regions in region[:16]:
    df_b3=newdf13[newdf13['region']==regions]    
    fig=px.line(df_b3, x="Year,month", y="Leads_per_ad",width =900,labels="region",color_discrete_sequence=['light blue']) 
    print(regions)
    fig.update_traces(mode='markers+lines')    
    fig.show()
# Out:
# Johor
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="42200675-f10b-4e77-aa7d-827e6fcb3d4e" class="plotly-graph-div" style="height:525px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("42200675-f10b-4e77-aa7d-827e6fcb3d4e")) {
#                     Plotly.newPlot(
#                         '42200675-f10b-4e77-aa7d-827e6fcb3d4e',
# ...

# %%
percent = df1.groupby(['platform']).agg({'Avg_leads': pd.Series.sum})
sum1 = percent['Avg_leads'].sum()
percentage = (percent/sum1)*100
percentage.round().astype(float)
# Out:
#             Avg_leads
# platform
# Android     45.850311
# Desktop     16.976832
# Mobile Web  25.073025
# iOS         12.099832

# %%
percent = df2_1.groupby(['platform']).agg({'Leads_per_ad': pd.Series.sum})
sum2 = percent['Leads_per_ad'].sum()
percentage = (percent/sum2)*100
percentage.round().astype(float)
# Out:
#             Leads_per_ad
# platform
# Android        27.829645
# Desktop        22.984871
# Mobile Web     25.626019
# iOS            23.559465

# %%
percent = Web.groupby(['channel_grouping']).agg({'Avg_leads': pd.Series.sum})
sum3_1 = percent['Avg_leads'].sum()
percentage = (percent/sum3_1)*100
percentage.round().astype(float)
# Out:
#                   Avg_leads
# channel_grouping
# (Other)            5.440598
# Direct            21.650631
# Display            1.182212
# Email              0.046086
# Organic Search    55.612548
# Paid Search       10.170191
# Referral           5.457746
# Social             0.439987

# %%
percent = App.groupby(['channel_grouping']).agg({'Avg_leads': pd.Series.sum})
sum3_2 = percent['Avg_leads'].sum()
percentage = (percent/sum3_2)*100
percentage.round().astype(float)
# Out:
#                   Avg_leads
# channel_grouping
# (Other)           43.416747
# Direct            45.419492
# Display            0.335815
# Email              0.086575
# Organic Search     0.000300
# Paid Search       10.735163
# Referral           0.005907

# %%
percent = Web1.groupby(['channel_grouping']).agg({'Leads_per_ad': pd.Series.sum})
sum3_3 = percent['Leads_per_ad'].sum()
percentage = (percent/sum3_3)*100
percentage
# Out:
#                   Leads_per_ad
# channel_grouping
# (Other)              12.383141
# Direct               12.888648
# Display              12.509772
# Email                11.332377
# Organic Search       13.493880
# Paid Search          12.753037
# Referral             12.793543
# Social               11.845602

# %%
percent = App1.groupby(['channel_grouping']).agg({'Leads_per_ad': pd.Series.sum})
sum3_3 = percent['Leads_per_ad'].sum()
percentage = (percent/sum3_3)*100
percentage
# Out:
#                   Leads_per_ad
# channel_grouping
# (Other)              21.566520
# Direct               22.710399
# Display               7.967965
# Email                 9.330476
# Organic Search        8.257618
# Paid Search          20.330918
# Referral              9.836103

# %%
percent = df5.groupby(['vertical']).agg({'Avg_leads': pd.Series.sum})
sum4 = percent['Avg_leads'].sum()
percentage = (percent/sum4)*100
percentage.round().astype(float)
# Out:
#             Avg_leads
# vertical
# Auto        35.169473
# Generalist  28.627660
# Jobs         4.957744
# Property    30.262812
# Services     0.982310

# %%
percent = newdf6.groupby(['vertical']).agg({'Leads_per_ad': pd.Series.mean})
sum5 = percent['Leads_per_ad'].sum()
percentage = (percent/sum5)*100
percentage
# Out:
#             Leads_per_ad
# vertical
# Auto           17.755063
# Generalist     17.863935
# Jobs           33.341132
# Property       17.052071
# Services       13.987799

# %%
percent = df7.groupby(['vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
sum6 = percent['Avg_leads'].sum()
percentage = (percent/sum6)*100
percentage.round().astype(float)
# Out:
#                         Avg_leads
# vertical   seller_type
# Auto       Private      14.200667
#            Pro          20.968806
# Generalist Private      24.015869
#            Pro           4.611791
# Jobs       Private       0.048044
#            Pro           4.909701
# Property   Private      12.255917
#            Pro          18.006896
# Services   Private       0.012888
#            Pro           0.969422

# %%
percent = newdf8.groupby(['vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
sum7 = percent['Leads_per_ad'].sum()
percentage = (percent/sum7)*100
percentage
# Out:
#                         Leads_per_ad
# vertical   seller_type
# Auto       Private         12.439299
#            Pro              8.065336
# Generalist Private          9.989659
#            Pro              7.399076
# Jobs       Private         10.929482
#            Pro             17.741244
# Property   Private         11.225633
#            Pro              7.967022
# Services   Private          6.831436
#            Pro              7.411814

# %%
percent = df9.groupby(['reply_type']).agg({'Avg_leads': pd.Series.sum})
sum8 = percent['Avg_leads'].sum()
percentage = (percent/sum8)*100
percentage.round().astype(float)
# Out:
#                      Avg_leads
# reply_type
# apply_now             0.408513
# call                 22.164240
# chat                 18.497112
# email                 1.775962
# show_contact_number  50.126105
# sms                   7.028068

# %%
percent = df10.groupby(['subcategory']).agg({'Avg_leads': pd.Series.sum})
sum9 = percent['Avg_leads'].sum()
percentage = (percent/sum9)*100
percentage.round().astype(float)
# Out:
#                                   Avg_leads
# subcategory
# Accessories for Phones & Gadgets   0.295062
# Accommodation & Homestays          0.279921
# Apartments                        11.509864
# Bags & Wallets                     0.277771
# Bed & Bath                         0.127939
# Business for Sale                  0.172734
# Cameras & Photography              0.463211
# Car Accessories & Parts            4.174757
# Cars                              21.837611
# Clothes                            0.356231
# Commercial Properties              1.132138
# Commercial Vehicle & Boats         0.896250
# Computers & Accessories            2.272108
# Food                               0.190172
# Furniture & Decoration             1.506612
# Games & Consoles                   1.291621
# Garden Items                       0.202808
# Health & Beauty                    0.277371
# Hobby & Collectibles               0.441266
# Home Appliances & Kitchen          1.642594
# ...

# %%
percent = newdf11.groupby(['subcategory']).agg({'Leads_per_ad': pd.Series.sum})
sum10 = percent['Leads_per_ad'].sum()
percentage = (percent/sum10)*100
percentage
# Out:
#                                   Leads_per_ad
# subcategory
# Accessories for Phones & Gadgets      2.210307
# Accommodation & Homestays             2.103449
# Apartments                            2.580443
# Bags & Wallets                        1.901597
# Bed & Bath                            1.936114
# Business for Sale                     3.168556
# Cameras & Photography                 2.307373
# Car Accessories & Parts               1.926518
# Cars                                  2.765849
# Clothes                               1.742329
# Commercial Properties                 1.975844
# Commercial Vehicle & Boats            2.715897
# Computers & Accessories               2.835853
# Food                                  1.901271
# Furniture & Decoration                2.108358
# Games & Consoles                      3.374990
# Garden Items                          1.881007
# Health & Beauty                       1.943046
# Hobby & Collectibles                  1.872990
# ...

# %%
percent = df12.groupby(['region']).agg({'Avg_leads': pd.Series.sum})
sum11 = percent['Avg_leads'].sum()
percentage = (percent/sum11)*100
percentage.round().astype(float)
# Out:
#               Avg_leads
# region
# Johor          9.496716
# Kedah          4.302518
# Kelantan       4.809007
# Kuala Lumpur  17.488453
# Labuan         0.052241
# Melaka         3.095188
# N. Sembilan    3.694657
# Pahang         2.582945
# Penang         8.214635
# Perak          4.285275
# Perlis         0.356810
# Putrajaya      0.553631
# Sabah          4.641857
# Sarawak        1.879801
# Selangor      31.862694
# Terengganu     2.683572

# %%
percent = newdf13.groupby(['region']).agg({'Leads_per_ad': pd.Series.sum})
sum12 = percent['Leads_per_ad'].sum()
percentage = (percent/sum12)*100
percentage
# Out:
#               Leads_per_ad
# region
# Johor             5.931645
# Kedah             6.580428
# Kelantan          6.862326
# Kuala Lumpur      6.126328
# Labuan            5.458016
# Melaka            6.357024
# N. Sembilan       6.488499
# Pahang            6.986934
# Penang            6.229376
# Perak             6.379570
# Perlis            6.534486
# Putrajaya         6.132122
# Sabah             5.919302
# Sarawak           5.133739
# Selangor          6.130518
# Terengganu        6.749687
