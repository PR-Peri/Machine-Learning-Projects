# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("HotStuff.csv")

# %%
data2 = pd.read_csv("Hot100AudioFeatures.csv")

# %%
#Merge two datasets

# %%
mergedata1_2 = pd.DataFrame.merge(data,data2, how ="inner")

# %%
mergedata1_2.to_csv('mergedata.csv')

# %%
cleandata = pd.read_csv('mergedata.csv')
cleandata
# Out:
#         Unnamed: 0  ... time_signature
# 0                0  ...            4.0
# 1                1  ...            4.0
# 2                2  ...            4.0
# 3                3  ...            4.0
# 4                4  ...            4.0
# ...            ...  ...            ...
# 112183      112183  ...            4.0
# 112184      112184  ...            4.0
# 112185      112185  ...            3.0
# 112186      112186  ...            4.0
# 112187      112187  ...            4.0
#
# [112188 rows x 31 columns]

# %%
#Drop Nan Value

# %%
cleandata= cleandata.dropna()

# %%
cleandata.to_csv('cleandata.csv')

# %%
#Reset WeekID's type

# %%
resetweek = pd.read_csv('cleandata.csv')

# %%
resetweek["WeekID"]= pd.to_datetime(resetweek["WeekID"])

# %%
#Drop un-used columns

# %%
dropcol=cleandata.drop(columns='Unnamed: 0')

dropcol2=dropcol.drop(columns='Unnamed: 0.1')

# %%
#reset index number

# %%
dropcol2.reset_index(drop=True, inplace=True)

# %%
dropcol2
# Out:
#                                                       url     WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1993-0... 1993-01-16
# 1       http://www.billboard.com/charts/hot-100/1993-0... 1993-02-13
# 2       http://www.billboard.com/charts/hot-100/1993-0... 1993-02-20
# 3       http://www.billboard.com/charts/hot-100/1993-0... 1993-02-27
# 4       http://www.billboard.com/charts/hot-100/1993-0... 1993-03-06
# ...                                                   ...        ...
# 137650  http://www.billboard.com/charts/hot-100/1983-1... 1983-11-05
# 137651  http://www.billboard.com/charts/hot-100/1983-1... 1983-11-12
# 137652  http://www.billboard.com/charts/hot-100/1983-1... 1983-11-19
# 137653  http://www.billboard.com/charts/hot-100/1983-1... 1983-11-26
# 137654  http://www.billboard.com/charts/hot-100/1983-1... 1983-12-03
#
#         Week Position  Song                            Performer  \
# 0                  15     7  Prince And The New Power Generation
# ...
